# %% [markdown]
# <a href="https://colab.research.google.com/github/anamitra-tech/ML-Projects/blob/main/EmotionTracker2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.1.2)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 52.8 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import os, warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model, Input, regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from gensim.models import Word2Vec

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import (classification_report, confusion_matrix,
                              accuracy_score, mean_absolute_error)
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.utils.class_weight import compute_class_weight

tf.random.set_seed(42)
np.random.seed(42)
os.makedirs('outputs', exist_ok=True)

print("=" * 65)
print("  ArvyaX — NN  |  TF-IDF + Embeddings + Relationship Modeling")
print("=" * 65)

# ══════════════════════════════════════════════════════════
# LOAD
# ══════════════════════════════════════════════════════════
train_raw = pd.read_csv('Sample_arvyax_reflective_dataset.xlsx - Dataset_120.csv')
test_raw  = pd.read_csv('arvyax_test_inputs_120.xlsx - Sheet1.csv')
print(f"\n  Train: {len(train_raw)}  |  Test: {len(test_raw)}")

# ══════════════════════════════════════════════════════════
# CONFIG
# ══════════════════════════════════════════════════════════
DROP_COLS    = {}
NUMERIC_COLS = ['duration_min', 'sleep_hours', 'energy_level', 'stress_level']
ORDINAL_COLS = ['time_of_day']
CAT_COLS     = ['previous_day_mood', 'face_emotion_hint', 'ambience_type']
TEXT_COL     = 'journal_text'
EMBED_DIM    = 8
TFIDF_DIM    = 300

# ══════════════════════════════════════════════════════════
# PREPROCESSING
# ══════════════════════════════════════════════════════════
print("\n[1] Preprocessing ...")

for df in [train_raw, test_raw]:
    for c in DROP_COLS:
        if c in df.columns:
            df.drop(columns=[c], inplace=True)

# time_of_day → ordinal
TIME_MAP = {'morning':4,'earlymorning':4,'early_morning':4,
            'afternoon':2,'evening':3,'night':1}
def map_time(v):
    return TIME_MAP.get(str(v).strip().lower().replace(' ',''), 2)

train_raw['time_of_day'] = train_raw['time_of_day'].apply(map_time)
test_raw['time_of_day']  = test_raw['time_of_day'].apply(map_time)

# Numeric NaN → train median
print("  Numeric medians:")
for col in NUMERIC_COLS:
    train_raw[col] = pd.to_numeric(train_raw[col], errors='coerce')
    test_raw[col]  = pd.to_numeric(test_raw[col],  errors='coerce')
    med = train_raw[col].median()
    train_raw[col] = train_raw[col].fillna(med)
    test_raw[col]  = test_raw[col].fillna(med)
    print(f"    {col:15s} = {med:.2f}")

# stress_level → scale 0-1 for relationship branch
stress_max = train_raw['stress_level'].max()
train_raw['stress_norm'] = train_raw['stress_level'] / stress_max
test_raw['stress_norm']  = test_raw['stress_level']  / stress_max

# Categorical NaN → 'neutral'
for col in CAT_COLS:
    train_raw[col] = train_raw[col].fillna('neutral').astype(str).str.strip().str.lower()
    test_raw[col]  = test_raw[col].fillna('neutral').astype(str).str.strip().str.lower()

# reflection_quality → fill + lowercase
if 'reflection_quality' in train_raw.columns:
    train_raw['reflection_quality'] = train_raw['reflection_quality'].fillna('unknown').astype(str).str.strip().str.lower()
# test may not have reflection_quality
if 'reflection_quality' not in test_raw.columns:
    test_raw['reflection_quality'] = 'unknown'
else:
    test_raw['reflection_quality']  = test_raw['reflection_quality'].fillna('unknown').astype(str).str.strip().str.lower()

# Text NaN → 'no reflection'
train_raw[TEXT_COL] = train_raw[TEXT_COL].fillna('no reflection').astype(str)
test_raw[TEXT_COL]  = test_raw[TEXT_COL].fillna('no reflection').astype(str)

# Merge calm+neutral (reduces confusion between near-identical classes)
MERGE_MAP = {'calm': 'calm_neutral', 'neutral': 'calm_neutral'}
train_raw['emotional_state'] = train_raw['emotional_state'].map(
    lambda x: MERGE_MAP.get(str(x).strip().lower(), str(x).strip().lower()))

print(f"\n  Classes after calm+neutral merge:")
for cls, cnt in train_raw['emotional_state'].value_counts().items():
    print(f"    {cls:15s} {cnt:3d} ({cnt/len(train_raw)*100:.1f}%)")

# ══════════════════════════════════════════════════════════
# WORD2VEC — categorical + journal text corpus
# ══════════════════════════════════════════════════════════
print("\n[2] Training Word2Vec ...")

def tokenize(value):
    return str(value).strip().lower().replace(' ','_').split('_')

corpus = []
for col in CAT_COLS + ['reflection_quality']:
    for val in pd.concat([train_raw[col], test_raw[col]]).unique():
        corpus.append(tokenize(val))
for text in train_raw[TEXT_COL]:
    tokens = str(text).lower().split()
    if tokens:
        corpus.append(tokens)

w2v = Word2Vec(sentences=corpus, vector_size=EMBED_DIM,
               window=3, min_count=1, workers=4, seed=42, epochs=100)

def get_emb(value):
    tokens = tokenize(value)
    vecs = [w2v.wv[t] if t in w2v.wv else np.zeros(EMBED_DIM) for t in tokens]
    return np.mean(vecs, axis=0)

def embed_col(series):
    return np.vstack([get_emb(v) for v in series]).astype(np.float32)

print(f"  Vocabulary size: {len(w2v.wv)}")

# ══════════════════════════════════════════════════════════
# TF-IDF on journal_text
# ══════════════════════════════════════════════════════════
print("\n[3] TF-IDF on journal_text ...")

tfidf    = TfidfVectorizer(max_features=TFIDF_DIM, ngram_range=(1,2),
                            sublinear_tf=True, min_df=2, lowercase=True)
tfidf_tr = tfidf.fit_transform(train_raw[TEXT_COL]).toarray().astype(np.float32)
tfidf_te = tfidf.transform(test_raw[TEXT_COL]).toarray().astype(np.float32)
print(f"  TF-IDF shape: {tfidf_tr.shape}")

# ══════════════════════════════════════════════════════════
# BUILD ALL FEATURE ARRAYS
# ══════════════════════════════════════════════════════════
print("\n[4] Building feature arrays ...")

NUM_FEAT  = NUMERIC_COLS + ORDINAL_COLS   # 5 features

scaler    = StandardScaler()
X_num_tr  = scaler.fit_transform(train_raw[NUM_FEAT].values.astype(float)).astype(np.float32)
X_num_te  = scaler.transform(test_raw[NUM_FEAT].values.astype(float)).astype(np.float32)

# stress_level as standalone (for relationship branch)
X_stress_tr = train_raw['stress_norm'].values.astype(np.float32).reshape(-1,1)
X_stress_te = test_raw['stress_norm'].values.astype(np.float32).reshape(-1,1)

# Word2Vec embeddings for categorical cols
mood_emb_tr = embed_col(train_raw['previous_day_mood'])
mood_emb_te = embed_col(test_raw['previous_day_mood'])

emo_emb_tr  = embed_col(train_raw['face_emotion_hint'])   # used in relationship branch
emo_emb_te  = embed_col(test_raw['face_emotion_hint'])

amb_emb_tr  = embed_col(train_raw['ambience_type'])
amb_emb_te  = embed_col(test_raw['ambience_type'])

rq_emb_tr   = embed_col(train_raw['reflection_quality'])  # used in relationship branch
rq_emb_te   = embed_col(test_raw['reflection_quality'])

print(f"  TF-IDF       : {tfidf_tr.shape[1]}")
print(f"  Numeric      : {X_num_tr.shape[1]}")
print(f"  Stress       : 1  (relationship branch)")
print(f"  face_emotion : {emo_emb_tr.shape[1]}  (relationship branch)")
print(f"  refl_quality : {rq_emb_tr.shape[1]}  (relationship branch)")
print(f"  mood_emb     : {mood_emb_tr.shape[1]}")
print(f"  ambience_emb : {amb_emb_tr.shape[1]}")

# ══════════════════════════════════════════════════════════
# TARGETS
# ══════════════════════════════════════════════════════════
print("\n[5] Encoding targets ...")

le_state = LabelEncoder()
y_state  = le_state.fit_transform(train_raw['emotional_state'])
y_intens = train_raw['intensity'].fillna(2).astype(float).values  # regression target

N_CLASSES = len(le_state.classes_)
print(f"  Y1 classes ({N_CLASSES}): {list(le_state.classes_)}")
print(f"  Y2 intensity range: {y_intens.min():.0f} – {y_intens.max():.0f}")

# Class weights for Y1
cw_arr  = compute_class_weight('balanced', classes=np.unique(y_state), y=y_state)
cw_dict = dict(enumerate(cw_arr))
sample_w = np.array([cw_dict[c] for c in y_state], dtype=np.float32)

# ══════════════════════════════════════════════════════════
# TRAIN / VAL SPLIT  80 / 20
# ══════════════════════════════════════════════════════════
print("\n[6] Train/Val split 80/20 ...")

tr_i, val_i = train_test_split(
    np.arange(len(train_raw)), test_size=0.2,
    random_state=42, stratify=y_state)

def sp(a): return a[tr_i], a[val_i]

Xtf_tr,  Xtf_val  = sp(tfidf_tr)
Xnum_tr, Xnum_val = sp(X_num_tr)
Xstr_tr, Xstr_val = sp(X_stress_tr)
Xemo_tr, Xemo_val = sp(emo_emb_tr)
Xrq_tr,  Xrq_val  = sp(rq_emb_tr)
Xmood_tr,Xmood_val= sp(mood_emb_tr)
Xamb_tr, Xamb_val = sp(amb_emb_tr)

ys_tr, ys_val = sp(y_state)
yi_tr, yi_val = sp(y_intens)
sw_tr         = sample_w[tr_i]

print(f"  Train:{len(tr_i)}  Val:{len(val_i)}  Test:{len(test_raw)}")

# ══════════════════════════════════════════════════════════
# DATA AUGMENTATION — Gaussian noise on numeric + tfidf
# ══════════════════════════════════════════════════════════
def augment_all(arrays_list, ys, yi, sw, n=3, noise=0.06):
    aug = [list(arrays_list)]
    ya, yia, swa = [ys], [yi], [sw]
    for _ in range(n):
        noisy = []
        for arr in arrays_list:
            n_arr = arr + np.random.normal(0, noise, arr.shape).astype(np.float32)
            noisy.append(n_arr)
        aug.append(noisy)
        ya.append(ys); yia.append(yi); swa.append(sw)
    stacked = [np.vstack([a[i] for a in aug]) for i in range(len(arrays_list))]
    return stacked, np.concatenate(ya), np.concatenate(yia), np.concatenate(swa)

train_arrays = [Xtf_tr, Xnum_tr, Xstr_tr, Xemo_tr, Xrq_tr, Xmood_tr, Xamb_tr]
aug_arrays, ys_aug, yi_aug, _ = augment_all(train_arrays, ys_tr, yi_tr, sw_tr)
Xtf_aug, Xnum_aug, Xstr_aug, Xemo_aug, Xrq_aug, Xmood_aug, Xamb_aug = aug_arrays

print(f"\n  After augmentation: {len(ys_aug)} samples (was {len(ys_tr)})")

# ══════════════════════════════════════════════════════════
# NEURAL NETWORK  — Multi-Input Multi-Output
# ══════════════════════════════════════════════════════════
print("\n[7] Building Neural Network ...")

L2 = 1e-4

def build_model():
    reg = regularizers.l2(L2)

    # ── INPUT 1: TF-IDF journal_text (300-dim) ──
    tfidf_in  = Input(shape=(TFIDF_DIM,), name='tfidf')
    x_text    = layers.Dense(128, activation='relu', kernel_regularizer=reg)(tfidf_in)
    x_text    = layers.BatchNormalization()(x_text)
    x_text    = layers.Dropout(0.2)(x_text)
    x_text    = layers.Dense(64, activation='relu', kernel_regularizer=reg)(x_text)
    # Branch A output: 64-dim text representation

    # ── INPUT 2: stress_level (1-dim scalar) ──
    stress_in = Input(shape=(1,), name='stress')

    # ── INPUT 3: face_emotion_hint Word2Vec (8-dim) ──
    emo_in    = Input(shape=(EMBED_DIM,), name='face_emotion')

    # ── INPUT 4: reflection_quality Word2Vec (8-dim) ──
    rq_in     = Input(shape=(EMBED_DIM,), name='refl_quality')

    # ── RELATIONSHIP BRANCH ──
    # Models the relationship between stress_level,
    # face_emotion_hint, journal_text and reflection_quality
    rel_concat = layers.Concatenate(name='relationship_inputs')(
        [x_text, stress_in, emo_in, rq_in])   # 64+1+8+8 = 81
    x_rel = layers.Dense(64, activation='relu',
                          kernel_regularizer=reg, name='rel_dense1')(rel_concat)
    x_rel = layers.BatchNormalization()(x_rel)
    x_rel = layers.Dropout(0.15)(x_rel)
    x_rel = layers.Dense(32, activation='relu',
                          kernel_regularizer=reg, name='rel_dense2')(x_rel)
    # Branch B output: 32-dim relationship representation

    # ── INPUT 5: other numeric + ordinal (5-dim) ──
    num_in    = Input(shape=(len(NUM_FEAT),), name='numeric')
    x_num     = layers.Dense(32, activation='relu', kernel_regularizer=reg)(num_in)
    x_num     = layers.BatchNormalization()(x_num)
    x_num     = layers.Dropout(0.1)(x_num)
    x_num     = layers.Dense(16, activation='relu', kernel_regularizer=reg)(x_num)
    # Branch C output: 16-dim numeric representation

    # ── INPUT 6: previous_day_mood (8-dim) ──
    mood_in   = Input(shape=(EMBED_DIM,), name='mood')

    # ── INPUT 7: ambience_type (8-dim) ──
    amb_in    = Input(shape=(EMBED_DIM,), name='ambience')

    # ── MERGE ALL BRANCHES ──
    # 64(text) + 32(relationship) + 16(numeric) + 8(mood) + 8(ambience) = 128
    # Note: stress, face_emotion, refl_quality already consumed in relationship branch
    merged = layers.Concatenate(name='all_merged')(
        [x_text, x_rel, x_num, mood_in, amb_in])

    # ── SHARED HIDDEN ──
    h = layers.Dense(64, activation='relu', kernel_regularizer=reg)(merged)
    h = layers.BatchNormalization()(h)
    h = layers.Dropout(0.15)(h)
    h = layers.Dense(32, activation='relu', kernel_regularizer=reg)(h)
    h = layers.BatchNormalization()(h)
    h = layers.Dropout(0.1)(h)

    # ── HEAD 1: emotional_state → Classification (Softmax) ──
    h1 = layers.Dense(32, activation='relu',
                       kernel_regularizer=reg, name='state_head')(h)
    h1 = layers.Dropout(0.1)(h1)
    out_state = layers.Dense(N_CLASSES, activation='softmax',
                              name='emotional_state')(h1)

    # ── HEAD 2: intensity → Regression (Linear) ──
    h2 = layers.Dense(16, activation='relu',
                       kernel_regularizer=reg, name='intensity_head')(h)
    out_intens = layers.Dense(1, activation='linear',
                               name='intensity')(h2)

    model = Model(
        inputs  = [tfidf_in, num_in, stress_in, emo_in, rq_in, mood_in, amb_in],
        outputs = [out_state, out_intens],
        name    = 'ArvyaX_MultiInput'
    )
    return model

model = build_model()

model.compile(
    optimizer = keras.optimizers.Adam(learning_rate=3e-4),
    loss = {
        'emotional_state': 'sparse_categorical_crossentropy',
        'intensity':        'mse',
    },
    loss_weights = {'emotional_state': 1.0, 'intensity': 0.5},
    metrics = {
        'emotional_state': ['accuracy'],
        'intensity':        ['mae'],
    }
)

model.summary()

# ══════════════════════════════════════════════════════════
# PREPARE INPUT DICTS
# ══════════════════════════════════════════════════════════
def make_inputs(tf, num, stress, emo, rq, mood, amb):
    return {
        'tfidf':        tf,
        'numeric':      num,
        'stress':       stress,
        'face_emotion': emo,
        'refl_quality': rq,
        'mood':         mood,
        'ambience':     amb,
    }

X_train_in = make_inputs(Xtf_aug, Xnum_aug, Xstr_aug,
                          Xemo_aug, Xrq_aug, Xmood_aug, Xamb_aug)
X_val_in   = make_inputs(Xtf_val, Xnum_val, Xstr_val,
                          Xemo_val, Xrq_val, Xmood_val, Xamb_val)
X_test_in  = make_inputs(tfidf_te, X_num_te, X_stress_te,
                          emo_emb_te, rq_emb_te, mood_emb_te, amb_emb_te)

Y_train    = {'emotional_state': ys_aug, 'intensity': yi_aug}
Y_val      = {'emotional_state': ys_val, 'intensity': yi_val}

# ══════════════════════════════════════════════════════════
# TRAIN
# ══════════════════════════════════════════════════════════
print("\n[8] Training ...")

callbacks = [
    EarlyStopping(monitor='val_emotional_state_accuracy', mode='max',
                  patience=30, restore_best_weights=True, verbose=0),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                      patience=12, min_lr=1e-6, verbose=0),
]


# ── Compute per-sample weights from class weights (augmented data) ──
# Keras 3.x does NOT support class_weight or sample_weight dict
# for multi-output models. Workaround: build a tf.data.Dataset
# that bundles (inputs, outputs, sample_weights) as a single tuple.
sw_aug_arr = np.array([cw_dict[c] for c in ys_aug], dtype=np.float32)

import tensorflow as _tf

def make_dataset(x_dict, y_dict, sw, batch_size, shuffle=False):
    ds = _tf.data.Dataset.from_tensor_slices((x_dict, y_dict, sw))
    if shuffle:
        ds = ds.shuffle(len(sw), seed=42)
    return ds.batch(batch_size).prefetch(_tf.data.AUTOTUNE)

BATCH = 8
train_ds = make_dataset(X_train_in, Y_train, sw_aug_arr,    BATCH, shuffle=True)
val_ds   = make_dataset(X_val_in,   Y_val,
                        np.ones(len(ys_val), dtype=np.float32), BATCH)

history = model.fit(
    train_ds,
    validation_data = val_ds,
    epochs          = 300,
    callbacks       = callbacks,
    verbose         = 1,
)

# ══════════════════════════════════════════════════════════
# EVALUATE
# ══════════════════════════════════════════════════════════
print("\n[9] Validation results ...")

val_preds   = model.predict(X_val_in, verbose=0)
ys_pred     = np.argmax(val_preds[0], axis=1)
yi_pred_raw = val_preds[1].flatten()
yi_pred_r   = np.clip(np.round(yi_pred_raw), 1, 5).astype(int)

s_acc = accuracy_score(ys_val, ys_pred)
mae   = mean_absolute_error(yi_val, yi_pred_raw)

print(f"\n  ── Y1: Emotional State (acc={s_acc:.3f}) ──")
print(classification_report(
    le_state.inverse_transform(ys_val),
    le_state.inverse_transform(ys_pred),
    zero_division=0))

print(f"\n  ── Y2: Intensity Regression (MAE={mae:.3f}) ──")
print(f"  True   : {yi_val[:10].astype(int).tolist()}")
print(f"  Pred   : {yi_pred_r[:10].tolist()}")

# ══════════════════════════════════════════════════════════
# PLOTS
# ══════════════════════════════════════════════════════════
print("\n[10] Saving plots ...")

# Training curves
h  = history.history
fig, axes = plt.subplots(2, 2, figsize=(13, 9))
def plot_h(ax, key, title):
    ax.plot(h.get(key,[]),        label='train', color='#534AB7', lw=2)
    ax.plot(h.get('val_'+key,[]), label='val',   color='#993C1D', lw=2, ls='--')
    ax.set_title(title); ax.set_xlabel('Epoch'); ax.legend(); ax.grid(alpha=0.3)

plot_h(axes[0,0], 'emotional_state_accuracy', 'Y1 Accuracy')
plot_h(axes[0,1], 'intensity_mae',             'Y2 MAE')
plot_h(axes[1,0], 'emotional_state_loss',      'Y1 Loss')
plot_h(axes[1,1], 'loss',                      'Total Loss')
plt.tight_layout()
plt.savefig('outputs/01_training_curves.png', dpi=120, bbox_inches='tight')
plt.close()

# Confusion matrix + intensity scatter
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
cm = confusion_matrix(ys_val, ys_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=le_state.classes_,
            yticklabels=le_state.classes_, ax=axes[0])
axes[0].set_title(f'Y1 Emotional State  (acc={s_acc:.2f})')
axes[0].set_xlabel('Predicted'); axes[0].set_ylabel('True')

axes[1].scatter(yi_val, yi_pred_raw, alpha=0.6, color='#534AB7', s=60)
axes[1].plot([1,5],[1,5],'r--', lw=1.5, label='perfect')
axes[1].set_xlabel('True Intensity'); axes[1].set_ylabel('Predicted (continuous)')
axes[1].set_title(f'Y2 Intensity Regression  (MAE={mae:.2f})')
axes[1].legend(); axes[1].grid(alpha=0.3)
plt.tight_layout()
plt.savefig('outputs/02_results.png', dpi=120, bbox_inches='tight')
plt.close()

# Architecture diagram (text-based visual)
fig, ax = plt.subplots(figsize=(12, 7))
ax.axis('off')
arch_text = (
    "Neural Network Architecture\n\n"
    "  INPUT 1: journal_text → TF-IDF(300) → Dense(128→64)  [Branch A: Text]\n"
    "                                                  ↓\n"
    "  INPUT 2: stress_level ──────────────────────────┤\n"
    "  INPUT 3: face_emotion_hint → Word2Vec(8) ────────┤→ Dense(64→32)  [RELATIONSHIP BRANCH]\n"
    "  INPUT 4: reflection_quality → Word2Vec(8) ────────┘  (models stress×emotion×text×quality)\n\n"
    "  INPUT 5: numeric/ordinal(5) → Dense(32→16)  [Branch C: Metadata]\n"
    "  INPUT 6: previous_day_mood → Word2Vec(8)\n"
    "  INPUT 7: ambience_type → Word2Vec(8)\n\n"
    "  ALL MERGED → Dense(64→32) [Shared Hidden]\n"
    "       ├──→ Dense(32→N) + Softmax  ═══ Y1: emotional_state  [CLASSIFICATION]\n"
    "       └──→ Dense(16→1) + Linear   ═══ Y2: intensity        [REGRESSION]\n\n"
    f"  Y1 Classes: {list(le_state.classes_)}\n"
    f"  Y2 Output : continuous 1.0–5.0  (rounded for display)\n"
)
ax.text(0.02, 0.95, arch_text, transform=ax.transAxes,
        fontsize=10, verticalalignment='top', fontfamily='monospace',
        bbox=dict(boxstyle='round', facecolor='#f0f0f0', alpha=0.8))
plt.tight_layout()
plt.savefig('outputs/03_architecture.png', dpi=120, bbox_inches='tight')
plt.close()

print("  Plots saved.")

# ══════════════════════════════════════════════════════════
# UNCERTAINTY
# ══════════════════════════════════════════════════════════
def get_confidence(proba):
    p = np.sort(proba)[::-1]
    conf   = float(p[0])
    margin = float(p[0]-p[1]) if len(p)>1 else 1.0
    return round(conf, 3), int(conf < 0.50 or margin < 0.15)

# ══════════════════════════════════════════════════════════
# RECOMMENDATION ENGINE
# Built from: predicted_state + intensity + stress + energy + time
# ══════════════════════════════════════════════════════════
ACTIVITY_MAP = {
    # (state, high_stress, low_energy) → activity
    ('anxious',      True,  True):  'box_breathing',
    ('anxious',      True,  False): 'box_breathing',
    ('anxious',      False, True):  'rest',
    ('anxious',      False, False): 'grounding',
    ('mixed',        True,  False): 'journaling',
    ('mixed',        False, False): 'light_planning',
    ('calm_neutral', False, False): 'light_planning',
    ('calm_neutral', True,  False): 'grounding',
    ('overwhelmed',  True,  False): 'box_breathing',
    ('overwhelmed',  False, False): 'rest',
    ('focused',      False, False): 'deep_work',
    ('focused',      True,  False): 'yoga',
    ('restless',     True,  False): 'grounding',
    ('restless',     False, False): 'movement',
}

WHEN_MAP = {
    # (state, rounded_intensity) → timing
    ('anxious',      5): 'now',
    ('anxious',      4): 'now',
    ('anxious',      3): 'within_15_min',
    ('anxious',      2): 'within_15_min',
    ('overwhelmed',  5): 'now',
    ('overwhelmed',  4): 'now',
    ('overwhelmed',  3): 'within_15_min',
    ('mixed',        4): 'within_15_min',
    ('mixed',        3): 'within_15_min',
    ('mixed',        2): 'later_today',
    ('restless',     4): 'within_15_min',
    ('restless',     3): 'within_15_min',
    ('calm_neutral', 2): 'later_today',
    ('calm_neutral', 1): 'tomorrow_morning',
    ('focused',      3): 'now',
    ('focused',      2): 'now',
    ('focused',      1): 'later_today',
}

MESSAGES = {
    'anxious':
        "Your reflection shows tension and inner noise. Before anything else, "
        "try 4 rounds of box breathing (4 counts in → hold → out → hold). "
        "Let the stress release before you plan your next step.",

    'overwhelmed':
        "You're carrying too much right now. The reflection and emotional signals "
        "both point to overload. Rest is not laziness here — it is the strategy. "
        "Pick just one small task after a break.",

    'mixed':
        "Your signals are split — some calm, some tension. Your journal shows "
        "conflicting thoughts. A short journaling or light planning session can "
        "help you clarify which direction to move.",

    'calm_neutral':
        "You're in a steady, balanced state. This is a good window for light "
        "planning or gentle focused work. Don't push too hard — maintain the calm.",

    'focused':
        "Your reflection shows mental clarity and readiness. Your face emotion "
        "and stress levels confirm it. This is your peak window — start your "
        "most important task right now.",

    'restless':
        "You seem physically or mentally unsettled. Some light movement — a short "
        "walk or stretching — can help discharge the restless energy before "
        "sitting back down to work.",
}

def decide_what(state, hs, lef):
    for k in [(state,hs,lef),(state,False,lef),(state,False,False)]:
        if k in ACTIVITY_MAP: return ACTIVITY_MAP[k]
    return 'pause'

def decide_when(state, intensity_rounded):
    for k in [(state, intensity_rounded),(state, 2)]:
        if k in WHEN_MAP: return WHEN_MAP[k]
    return 'later_today'

# ══════════════════════════════════════════════════════════
# TEST PREDICTIONS
# ══════════════════════════════════════════════════════════
print("\n[11] Generating test predictions ...")

te_preds    = model.predict(X_test_in, verbose=0)
s_probas    = te_preds[0]
yi_te_raw   = te_preds[1].flatten()
te_states   = le_state.inverse_transform(np.argmax(s_probas, axis=1))
te_intens_r = np.clip(np.round(yi_te_raw), 1, 5).astype(int)

records = []
for i in range(len(test_raw)):
    state     = te_states[i]
    intensity = int(te_intens_r[i])
    conf, unc = get_confidence(s_probas[i])

    stress_val = float(test_raw.iloc[i]['stress_level'])
    energy_val = float(test_raw.iloc[i]['energy_level'])
    hs  = stress_val >= 4
    lef = energy_val <= 2

    what    = decide_what(state, hs, lef)
    when    = decide_when(state, intensity)
    message = MESSAGES.get(state, "Take a moment to pause and check in.")

    records.append({
        'id':                  test_raw.iloc[i]['id'],
        'predicted_state':     state,
        'predicted_intensity': intensity,
        'intensity_raw':       round(float(yi_te_raw[i]), 2),
        'confidence':          conf,
        'uncertain_flag':      unc,
        'what_to_do':          what,
        'when_to_do':          when,
        'supportive_message':  message,
    })

pred_df = pd.DataFrame(records)

print("\n  ── Test Predictions ──")
print(pred_df[['id','predicted_state','predicted_intensity',
               'confidence','uncertain_flag','what_to_do','when_to_do']].to_string(index=False))

print("\n  ── Supportive Messages ──")
for _, r in pred_df.iterrows():
    print(f"\n  ID {r['id']} [{r['predicted_state'].upper()}, intensity={r['predicted_intensity']}]")
    print(f"  {r['supportive_message']}")

# Save
pred_df[['id','predicted_state','predicted_intensity',
         'confidence','uncertain_flag','what_to_do','when_to_do']].to_csv(
    'outputs/predictions.csv', index=False)
pred_df.to_csv('outputs/predictions_full.csv', index=False)
# Out:
# =================================================================
#   ArvyaX — NN  |  TF-IDF + Embeddings + Relationship Modeling
# =================================================================
#
#   Train: 1200  |  Test: 120
#
# [1] Preprocessing ...
#   Numeric medians:
#     duration_min    = 15.00
#     sleep_hours     = 6.00
#     energy_level    = 3.00
#     stress_level    = 3.00
#
#   Classes after calm+neutral merge:
#     calm_neutral    417 (34.8%)
#     restless        209 (17.4%)
#     focused         193 (16.1%)
#     mixed           191 (15.9%)
#     overwhelmed     190 (15.8%)
#
# [2] Training Word2Vec ...
#   Vocabulary size: 517
#
# [3] TF-IDF on journal_text ...
#   TF-IDF shape: (1200, 300)
#
# [4] Building feature arrays ...
#   TF-IDF       : 300
#   Numeric      : 5
#   Stress       : 1  (relationship branch)
#   face_emotion : 8  (relationship branch)
#   refl_quality : 8  (relationship branch)
#   mood_emb     : 8
#   ambience_emb : 8
#
# [5] Encoding targets ...
#   Y1 classes (5): ['calm_neutral', 'focused', 'mixed', 'overwhelmed', 'restless']
#   Y2 intensity range: 1 – 5
#
# [6] Train/Val split 80/20 ...
#   Train:960  Val:240  Test:120
#
#   After augmentation: 3840 samples (was 960)
#
# [7] Building Neural Network ...
# Model: "ArvyaX_MultiInput"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ tfidf (InputLayer)  │ (None, 300)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 128)       │     38,528 │ tfidf[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_6[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 64)        │      8,256 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stress (InputLayer) │ (None, 1)         │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ face_emotion        │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ refl_quality        │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ relationship_inputs │ (None, 81)        │          0 │ dense_7[0][0],    │
# │ (Concatenate)       │                   │            │ stress[0][0],     │
# │                     │                   │            │ face_emotion[0][… │
# │                     │                   │            │ refl_quality[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ numeric             │ (None, 5)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rel_dense1 (Dense)  │ (None, 64)        │      5,248 │ relationship_inp… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 32)        │        192 │ numeric[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ rel_dense1[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32)        │        128 │ dense_8[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 64)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 32)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rel_dense2 (Dense)  │ (None, 32)        │      2,080 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 16)        │        528 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mood (InputLayer)   │ (None, 8)         │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ambience            │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ all_merged          │ (None, 128)       │          0 │ dense_7[0][0],    │
# │ (Concatenate)       │                   │            │ rel_dense2[0][0], │
# │                     │                   │            │ dense_9[0][0],    │
# │                     │                   │            │ mood[0][0],       │
# │                     │                   │            │ ambience[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 64)        │      8,256 │ all_merged[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_10[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 64)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 32)        │      2,080 │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32)        │        128 │ dense_11[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 32)        │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ state_head (Dense)  │ (None, 32)        │      1,056 │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 32)        │          0 │ state_head[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ intensity_head      │ (None, 16)        │        528 │ dropout_10[0][0]  │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ emotional_state     │ (None, 5)         │        165 │ dropout_11[0][0]  │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ intensity (Dense)   │ (None, 1)         │         17 │ intensity_head[0… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 68,214 (266.46 KB)
#  Trainable params: 67,574 (263.96 KB)
#  Non-trainable params: 640 (2.50 KB)
# [8] Training ...
# Epoch 1/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - emotional_state_accuracy: 0.2003 - emotional_state_loss: 1.8237 - intensity_loss: 8.6555 - intensity_mae: 2.5003 - loss: 6.2108 - val_emotional_state_accuracy: 0.2000 - val_emotional_state_loss: 1.6739 - val_intensity_loss: 3.3614 - val_intensity_mae: 1.5136 - val_loss: 3.4139 - learning_rate: 3.0000e-04
# Epoch 2/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.2180 - emotional_state_loss: 1.7048 - intensity_loss: 3.3970 - intensity_mae: 1.5147 - loss: 3.4627 - val_emotional_state_accuracy: 0.1583 - val_emotional_state_loss: 1.6996 - val_intensity_loss: 2.3031 - val_intensity_mae: 1.2469 - val_loss: 2.9106 - learning_rate: 3.0000e-04
# Epoch 3/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.2227 - emotional_state_loss: 1.6686 - intensity_loss: 2.5420 - intensity_mae: 1.3366 - loss: 2.9991 - val_emotional_state_accuracy: 0.1375 - val_emotional_state_loss: 1.6711 - val_intensity_loss: 2.1202 - val_intensity_mae: 1.2096 - val_loss: 2.7907 - learning_rate: 3.0000e-04
# Epoch 4/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.2117 - emotional_state_loss: 1.6498 - intensity_loss: 2.2426 - intensity_mae: 1.2605 - loss: 2.8305 - val_emotional_state_accuracy: 0.2083 - val_emotional_state_loss: 1.6452 - val_intensity_loss: 2.0683 - val_intensity_mae: 1.2136 - val_loss: 2.7388 - learning_rate: 3.0000e-04
# Epoch 5/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.2195 - emotional_state_loss: 1.6446 - intensity_loss: 2.1277 - intensity_mae: 1.2419 - loss: 2.7679 - val_emotional_state_accuracy: 0.2000 - val_emotional_state_loss: 1.6399 - val_intensity_loss: 2.0290 - val_intensity_mae: 1.2031 - val_loss: 2.7140 - learning_rate: 3.0000e-04
# Epoch 6/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - emotional_state_accuracy: 0.2297 - emotional_state_loss: 1.6237 - intensity_loss: 2.0395 - intensity_mae: 1.2161 - loss: 2.7030 - val_emotional_state_accuracy: 0.1792 - val_emotional_state_loss: 1.6460 - val_intensity_loss: 2.0719 - val_intensity_mae: 1.2116 - val_loss: 2.7415 - learning_rate: 3.0000e-04
# Epoch 7/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.2333 - emotional_state_loss: 1.6188 - intensity_loss: 1.9643 - intensity_mae: 1.1949 - loss: 2.6605 - val_emotional_state_accuracy: 0.1708 - val_emotional_state_loss: 1.6348 - val_intensity_loss: 2.0786 - val_intensity_mae: 1.2204 - val_loss: 2.7337 - learning_rate: 3.0000e-04
# Epoch 8/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.2474 - emotional_state_loss: 1.5987 - intensity_loss: 1.9608 - intensity_mae: 1.1888 - loss: 2.6388 - val_emotional_state_accuracy: 0.1708 - val_emotional_state_loss: 1.6288 - val_intensity_loss: 2.1431 - val_intensity_mae: 1.2431 - val_loss: 2.7601 - learning_rate: 3.0000e-04
# Epoch 9/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.2424 - emotional_state_loss: 1.5921 - intensity_loss: 1.8710 - intensity_mae: 1.1703 - loss: 2.5874 - val_emotional_state_accuracy: 0.2083 - val_emotional_state_loss: 1.6244 - val_intensity_loss: 2.0775 - val_intensity_mae: 1.2258 - val_loss: 2.7230 - learning_rate: 3.0000e-04
# Epoch 10/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.2609 - emotional_state_loss: 1.5765 - intensity_loss: 1.8438 - intensity_mae: 1.1568 - loss: 2.5583 - val_emotional_state_accuracy: 0.2208 - val_emotional_state_loss: 1.6163 - val_intensity_loss: 2.0319 - val_intensity_mae: 1.2078 - val_loss: 2.6922 - learning_rate: 3.0000e-04
# Epoch 11/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - emotional_state_accuracy: 0.2706 - emotional_state_loss: 1.5708 - intensity_loss: 1.8477 - intensity_mae: 1.1581 - loss: 2.5546 - val_emotional_state_accuracy: 0.2917 - val_emotional_state_loss: 1.6048 - val_intensity_loss: 2.0713 - val_intensity_mae: 1.2167 - val_loss: 2.7005 - learning_rate: 3.0000e-04
# Epoch 12/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.2792 - emotional_state_loss: 1.5550 - intensity_loss: 1.7549 - intensity_mae: 1.1358 - loss: 2.4926 - val_emotional_state_accuracy: 0.2792 - val_emotional_state_loss: 1.5997 - val_intensity_loss: 2.0787 - val_intensity_mae: 1.2195 - val_loss: 2.6993 - learning_rate: 3.0000e-04
# Epoch 13/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.2727 - emotional_state_loss: 1.5426 - intensity_loss: 1.7529 - intensity_mae: 1.1324 - loss: 2.4793 - val_emotional_state_accuracy: 0.2917 - val_emotional_state_loss: 1.5738 - val_intensity_loss: 2.0712 - val_intensity_mae: 1.2136 - val_loss: 2.6698 - learning_rate: 3.0000e-04
# Epoch 14/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.2953 - emotional_state_loss: 1.5110 - intensity_loss: 1.7073 - intensity_mae: 1.1141 - loss: 2.4251 - val_emotional_state_accuracy: 0.2792 - val_emotional_state_loss: 1.5594 - val_intensity_loss: 2.1721 - val_intensity_mae: 1.2322 - val_loss: 2.7060 - learning_rate: 3.0000e-04
# Epoch 15/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.2930 - emotional_state_loss: 1.5037 - intensity_loss: 1.6694 - intensity_mae: 1.1070 - loss: 2.3990 - val_emotional_state_accuracy: 0.2750 - val_emotional_state_loss: 1.5366 - val_intensity_loss: 2.1691 - val_intensity_mae: 1.2274 - val_loss: 2.6818 - learning_rate: 3.0000e-04
# Epoch 16/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.3104 - emotional_state_loss: 1.4984 - intensity_loss: 1.6230 - intensity_mae: 1.0898 - loss: 2.3706 - val_emotional_state_accuracy: 0.3125 - val_emotional_state_loss: 1.5159 - val_intensity_loss: 2.2128 - val_intensity_mae: 1.2368 - val_loss: 2.6831 - learning_rate: 3.0000e-04
# Epoch 17/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.3370 - emotional_state_loss: 1.4528 - intensity_loss: 1.5925 - intensity_mae: 1.0821 - loss: 2.3099 - val_emotional_state_accuracy: 0.3042 - val_emotional_state_loss: 1.5079 - val_intensity_loss: 2.2636 - val_intensity_mae: 1.2444 - val_loss: 2.7007 - learning_rate: 3.0000e-04
# Epoch 18/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.3469 - emotional_state_loss: 1.4227 - intensity_loss: 1.5617 - intensity_mae: 1.0638 - loss: 2.2645 - val_emotional_state_accuracy: 0.2917 - val_emotional_state_loss: 1.5012 - val_intensity_loss: 2.3969 - val_intensity_mae: 1.2721 - val_loss: 2.7607 - learning_rate: 3.0000e-04
# Epoch 19/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.3536 - emotional_state_loss: 1.4186 - intensity_loss: 1.5878 - intensity_mae: 1.0642 - loss: 2.2737 - val_emotional_state_accuracy: 0.3250 - val_emotional_state_loss: 1.4827 - val_intensity_loss: 2.3806 - val_intensity_mae: 1.2606 - val_loss: 2.7342 - learning_rate: 3.0000e-04
# Epoch 20/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - emotional_state_accuracy: 0.3674 - emotional_state_loss: 1.3731 - intensity_loss: 1.4764 - intensity_mae: 1.0405 - loss: 2.1726 - val_emotional_state_accuracy: 0.3417 - val_emotional_state_loss: 1.4645 - val_intensity_loss: 2.3786 - val_intensity_mae: 1.2742 - val_loss: 2.7152 - learning_rate: 3.0000e-04
# Epoch 21/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.3935 - emotional_state_loss: 1.3458 - intensity_loss: 1.4812 - intensity_mae: 1.0362 - loss: 2.1478 - val_emotional_state_accuracy: 0.3375 - val_emotional_state_loss: 1.4821 - val_intensity_loss: 2.3688 - val_intensity_mae: 1.2615 - val_loss: 2.7281 - learning_rate: 3.0000e-04
# Epoch 22/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.3885 - emotional_state_loss: 1.3233 - intensity_loss: 1.4229 - intensity_mae: 1.0153 - loss: 2.0964 - val_emotional_state_accuracy: 0.3583 - val_emotional_state_loss: 1.4693 - val_intensity_loss: 2.3758 - val_intensity_mae: 1.2649 - val_loss: 2.7190 - learning_rate: 3.0000e-04
# Epoch 23/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.4182 - emotional_state_loss: 1.2915 - intensity_loss: 1.4039 - intensity_mae: 0.9972 - loss: 2.0553 - val_emotional_state_accuracy: 0.3542 - val_emotional_state_loss: 1.4689 - val_intensity_loss: 2.4359 - val_intensity_mae: 1.2816 - val_loss: 2.7488 - learning_rate: 3.0000e-04
# Epoch 24/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.4349 - emotional_state_loss: 1.2605 - intensity_loss: 1.3881 - intensity_mae: 1.0051 - loss: 2.0166 - val_emotional_state_accuracy: 0.4292 - val_emotional_state_loss: 1.4452 - val_intensity_loss: 2.3359 - val_intensity_mae: 1.2556 - val_loss: 2.6752 - learning_rate: 3.0000e-04
# Epoch 25/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - emotional_state_accuracy: 0.4398 - emotional_state_loss: 1.2394 - intensity_loss: 1.3462 - intensity_mae: 0.9867 - loss: 1.9747 - val_emotional_state_accuracy: 0.4167 - val_emotional_state_loss: 1.4011 - val_intensity_loss: 2.4453 - val_intensity_mae: 1.2967 - val_loss: 2.6861 - learning_rate: 3.0000e-04
# Epoch 26/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.4693 - emotional_state_loss: 1.1961 - intensity_loss: 1.3125 - intensity_mae: 0.9675 - loss: 1.9146 - val_emotional_state_accuracy: 0.4417 - val_emotional_state_loss: 1.3774 - val_intensity_loss: 2.3813 - val_intensity_mae: 1.2762 - val_loss: 2.6303 - learning_rate: 1.5000e-04
# Epoch 27/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.4625 - emotional_state_loss: 1.1933 - intensity_loss: 1.2391 - intensity_mae: 0.9500 - loss: 1.8751 - val_emotional_state_accuracy: 0.4542 - val_emotional_state_loss: 1.3609 - val_intensity_loss: 2.4921 - val_intensity_mae: 1.3081 - val_loss: 2.6693 - learning_rate: 1.5000e-04
# Epoch 28/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.4693 - emotional_state_loss: 1.1593 - intensity_loss: 1.2776 - intensity_mae: 0.9505 - loss: 1.8605 - val_emotional_state_accuracy: 0.4417 - val_emotional_state_loss: 1.3694 - val_intensity_loss: 2.4623 - val_intensity_mae: 1.3053 - val_loss: 2.6629 - learning_rate: 1.5000e-04
# Epoch 29/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.4888 - emotional_state_loss: 1.1414 - intensity_loss: 1.2374 - intensity_mae: 0.9422 - loss: 1.8224 - val_emotional_state_accuracy: 0.4292 - val_emotional_state_loss: 1.3707 - val_intensity_loss: 2.5150 - val_intensity_mae: 1.3084 - val_loss: 2.6906 - learning_rate: 1.5000e-04
# Epoch 30/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.4961 - emotional_state_loss: 1.1182 - intensity_loss: 1.1910 - intensity_mae: 0.9257 - loss: 1.7761 - val_emotional_state_accuracy: 0.4333 - val_emotional_state_loss: 1.3597 - val_intensity_loss: 2.5313 - val_intensity_mae: 1.3140 - val_loss: 2.6878 - learning_rate: 1.5000e-04
# Epoch 31/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.4906 - emotional_state_loss: 1.0956 - intensity_loss: 1.2028 - intensity_mae: 0.9230 - loss: 1.7595 - val_emotional_state_accuracy: 0.4458 - val_emotional_state_loss: 1.3553 - val_intensity_loss: 2.5262 - val_intensity_mae: 1.3205 - val_loss: 2.6809 - learning_rate: 1.5000e-04
# Epoch 32/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - emotional_state_accuracy: 0.5057 - emotional_state_loss: 1.1091 - intensity_loss: 1.1614 - intensity_mae: 0.9122 - loss: 1.7522 - val_emotional_state_accuracy: 0.4542 - val_emotional_state_loss: 1.3372 - val_intensity_loss: 2.6136 - val_intensity_mae: 1.3345 - val_loss: 2.7065 - learning_rate: 1.5000e-04
# Epoch 33/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - emotional_state_accuracy: 0.5052 - emotional_state_loss: 1.1015 - intensity_loss: 1.1596 - intensity_mae: 0.9093 - loss: 1.7437 - val_emotional_state_accuracy: 0.4625 - val_emotional_state_loss: 1.3110 - val_intensity_loss: 2.5843 - val_intensity_mae: 1.3344 - val_loss: 2.6656 - learning_rate: 1.5000e-04
# Epoch 34/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.5232 - emotional_state_loss: 1.0771 - intensity_loss: 1.1622 - intensity_mae: 0.9091 - loss: 1.7208 - val_emotional_state_accuracy: 0.4583 - val_emotional_state_loss: 1.3047 - val_intensity_loss: 2.6791 - val_intensity_mae: 1.3524 - val_loss: 2.7068 - learning_rate: 1.5000e-04
# Epoch 35/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.5372 - emotional_state_loss: 1.0544 - intensity_loss: 1.1419 - intensity_mae: 0.8968 - loss: 1.6879 - val_emotional_state_accuracy: 0.4625 - val_emotional_state_loss: 1.2862 - val_intensity_loss: 2.6462 - val_intensity_mae: 1.3532 - val_loss: 2.6718 - learning_rate: 1.5000e-04
# Epoch 36/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.5396 - emotional_state_loss: 1.0429 - intensity_loss: 1.0774 - intensity_mae: 0.8774 - loss: 1.6441 - val_emotional_state_accuracy: 0.4792 - val_emotional_state_loss: 1.2865 - val_intensity_loss: 2.7475 - val_intensity_mae: 1.3802 - val_loss: 2.7228 - learning_rate: 1.5000e-04
# Epoch 37/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - emotional_state_accuracy: 0.5510 - emotional_state_loss: 1.0266 - intensity_loss: 1.1128 - intensity_mae: 0.8883 - loss: 1.6456 - val_emotional_state_accuracy: 0.4708 - val_emotional_state_loss: 1.2667 - val_intensity_loss: 2.7099 - val_intensity_mae: 1.3705 - val_loss: 2.6842 - learning_rate: 1.5000e-04
# Epoch 38/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.5669 - emotional_state_loss: 1.0022 - intensity_loss: 1.1199 - intensity_mae: 0.8840 - loss: 1.6248 - val_emotional_state_accuracy: 0.4833 - val_emotional_state_loss: 1.2707 - val_intensity_loss: 2.6793 - val_intensity_mae: 1.3640 - val_loss: 2.6730 - learning_rate: 1.5000e-04
# Epoch 39/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.5628 - emotional_state_loss: 0.9801 - intensity_loss: 1.1034 - intensity_mae: 0.8843 - loss: 1.5944 - val_emotional_state_accuracy: 0.5125 - val_emotional_state_loss: 1.2569 - val_intensity_loss: 2.6224 - val_intensity_mae: 1.3489 - val_loss: 2.6307 - learning_rate: 7.5000e-05
# Epoch 40/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.5724 - emotional_state_loss: 0.9698 - intensity_loss: 1.0572 - intensity_mae: 0.8612 - loss: 1.5609 - val_emotional_state_accuracy: 0.5125 - val_emotional_state_loss: 1.2536 - val_intensity_loss: 2.6837 - val_intensity_mae: 1.3625 - val_loss: 2.6581 - learning_rate: 7.5000e-05
# Epoch 41/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.5789 - emotional_state_loss: 0.9651 - intensity_loss: 1.0419 - intensity_mae: 0.8581 - loss: 1.5487 - val_emotional_state_accuracy: 0.5083 - val_emotional_state_loss: 1.2616 - val_intensity_loss: 2.6819 - val_intensity_mae: 1.3631 - val_loss: 2.6652 - learning_rate: 7.5000e-05
# Epoch 42/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.5846 - emotional_state_loss: 0.9551 - intensity_loss: 1.0348 - intensity_mae: 0.8482 - loss: 1.5351 - val_emotional_state_accuracy: 0.5042 - val_emotional_state_loss: 1.2429 - val_intensity_loss: 2.6680 - val_intensity_mae: 1.3595 - val_loss: 2.6395 - learning_rate: 7.5000e-05
# Epoch 43/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.5807 - emotional_state_loss: 0.9353 - intensity_loss: 1.0448 - intensity_mae: 0.8538 - loss: 1.5203 - val_emotional_state_accuracy: 0.5083 - val_emotional_state_loss: 1.2595 - val_intensity_loss: 2.7232 - val_intensity_mae: 1.3742 - val_loss: 2.6837 - learning_rate: 7.5000e-05
# Epoch 44/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.5995 - emotional_state_loss: 0.9189 - intensity_loss: 1.0277 - intensity_mae: 0.8416 - loss: 1.4953 - val_emotional_state_accuracy: 0.5042 - val_emotional_state_loss: 1.2562 - val_intensity_loss: 2.7284 - val_intensity_mae: 1.3694 - val_loss: 2.6830 - learning_rate: 7.5000e-05
# Epoch 45/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.6016 - emotional_state_loss: 0.9183 - intensity_loss: 1.0583 - intensity_mae: 0.8589 - loss: 1.5100 - val_emotional_state_accuracy: 0.5167 - val_emotional_state_loss: 1.2401 - val_intensity_loss: 2.7052 - val_intensity_mae: 1.3659 - val_loss: 2.6553 - learning_rate: 7.5000e-05
# Epoch 46/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.5958 - emotional_state_loss: 0.9258 - intensity_loss: 1.0018 - intensity_mae: 0.8433 - loss: 1.4893 - val_emotional_state_accuracy: 0.5250 - val_emotional_state_loss: 1.2366 - val_intensity_loss: 2.7459 - val_intensity_mae: 1.3795 - val_loss: 2.6722 - learning_rate: 7.5000e-05
# Epoch 47/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.5977 - emotional_state_loss: 0.9185 - intensity_loss: 1.0155 - intensity_mae: 0.8379 - loss: 1.4888 - val_emotional_state_accuracy: 0.5167 - val_emotional_state_loss: 1.2388 - val_intensity_loss: 2.7229 - val_intensity_mae: 1.3682 - val_loss: 2.6629 - learning_rate: 7.5000e-05
# Epoch 48/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.6128 - emotional_state_loss: 0.9126 - intensity_loss: 0.9901 - intensity_mae: 0.8326 - loss: 1.4703 - val_emotional_state_accuracy: 0.5333 - val_emotional_state_loss: 1.2262 - val_intensity_loss: 2.7426 - val_intensity_mae: 1.3774 - val_loss: 2.6601 - learning_rate: 7.5000e-05
# Epoch 49/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.6315 - emotional_state_loss: 0.8708 - intensity_loss: 1.0184 - intensity_mae: 0.8437 - loss: 1.4426 - val_emotional_state_accuracy: 0.5292 - val_emotional_state_loss: 1.2275 - val_intensity_loss: 2.7444 - val_intensity_mae: 1.3705 - val_loss: 2.6622 - learning_rate: 7.5000e-05
# Epoch 50/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.6120 - emotional_state_loss: 0.8971 - intensity_loss: 0.9876 - intensity_mae: 0.8221 - loss: 1.4535 - val_emotional_state_accuracy: 0.5292 - val_emotional_state_loss: 1.2376 - val_intensity_loss: 2.7286 - val_intensity_mae: 1.3671 - val_loss: 2.6645 - learning_rate: 7.5000e-05
# Epoch 51/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.6307 - emotional_state_loss: 0.8628 - intensity_loss: 0.9823 - intensity_mae: 0.8270 - loss: 1.4165 - val_emotional_state_accuracy: 0.5083 - val_emotional_state_loss: 1.2314 - val_intensity_loss: 2.7119 - val_intensity_mae: 1.3643 - val_loss: 2.6499 - learning_rate: 3.7500e-05
# Epoch 52/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.6427 - emotional_state_loss: 0.8501 - intensity_loss: 1.0036 - intensity_mae: 0.8388 - loss: 1.4145 - val_emotional_state_accuracy: 0.5167 - val_emotional_state_loss: 1.2422 - val_intensity_loss: 2.7369 - val_intensity_mae: 1.3677 - val_loss: 2.6732 - learning_rate: 3.7500e-05
# Epoch 53/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.6198 - emotional_state_loss: 0.8809 - intensity_loss: 0.9464 - intensity_mae: 0.8100 - loss: 1.4166 - val_emotional_state_accuracy: 0.5333 - val_emotional_state_loss: 1.2344 - val_intensity_loss: 2.7826 - val_intensity_mae: 1.3775 - val_loss: 2.6882 - learning_rate: 3.7500e-05
# Epoch 54/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.6242 - emotional_state_loss: 0.8583 - intensity_loss: 0.9923 - intensity_mae: 0.8300 - loss: 1.4169 - val_emotional_state_accuracy: 0.5333 - val_emotional_state_loss: 1.2223 - val_intensity_loss: 2.7274 - val_intensity_mae: 1.3668 - val_loss: 2.6485 - learning_rate: 3.7500e-05
# Epoch 55/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.6380 - emotional_state_loss: 0.8510 - intensity_loss: 0.9450 - intensity_mae: 0.8173 - loss: 1.3861 - val_emotional_state_accuracy: 0.5292 - val_emotional_state_loss: 1.2241 - val_intensity_loss: 2.7000 - val_intensity_mae: 1.3611 - val_loss: 2.6366 - learning_rate: 3.7500e-05
# Epoch 56/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.6385 - emotional_state_loss: 0.8550 - intensity_loss: 0.9780 - intensity_mae: 0.8324 - loss: 1.4066 - val_emotional_state_accuracy: 0.5333 - val_emotional_state_loss: 1.2333 - val_intensity_loss: 2.7062 - val_intensity_mae: 1.3671 - val_loss: 2.6489 - learning_rate: 3.7500e-05
# Epoch 57/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.6542 - emotional_state_loss: 0.8140 - intensity_loss: 0.9532 - intensity_mae: 0.8124 - loss: 1.3531 - val_emotional_state_accuracy: 0.5333 - val_emotional_state_loss: 1.2304 - val_intensity_loss: 2.7034 - val_intensity_mae: 1.3627 - val_loss: 2.6446 - learning_rate: 3.7500e-05
# Epoch 58/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.6349 - emotional_state_loss: 0.8356 - intensity_loss: 0.9505 - intensity_mae: 0.8183 - loss: 1.3734 - val_emotional_state_accuracy: 0.5292 - val_emotional_state_loss: 1.2273 - val_intensity_loss: 2.7189 - val_intensity_mae: 1.3649 - val_loss: 2.6492 - learning_rate: 3.7500e-05
# Epoch 59/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.6349 - emotional_state_loss: 0.8432 - intensity_loss: 0.9967 - intensity_mae: 0.8360 - loss: 1.4040 - val_emotional_state_accuracy: 0.5333 - val_emotional_state_loss: 1.2271 - val_intensity_loss: 2.7067 - val_intensity_mae: 1.3615 - val_loss: 2.6430 - learning_rate: 3.7500e-05
# Epoch 60/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.6318 - emotional_state_loss: 0.8357 - intensity_loss: 0.9645 - intensity_mae: 0.8160 - loss: 1.3804 - val_emotional_state_accuracy: 0.5333 - val_emotional_state_loss: 1.2325 - val_intensity_loss: 2.7375 - val_intensity_mae: 1.3710 - val_loss: 2.6638 - learning_rate: 3.7500e-05
# Epoch 61/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.6435 - emotional_state_loss: 0.8412 - intensity_loss: 0.9583 - intensity_mae: 0.8227 - loss: 1.3828 - val_emotional_state_accuracy: 0.5333 - val_emotional_state_loss: 1.2228 - val_intensity_loss: 2.6965 - val_intensity_mae: 1.3599 - val_loss: 2.6335 - learning_rate: 3.7500e-05
# Epoch 62/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.6346 - emotional_state_loss: 0.8492 - intensity_loss: 0.9545 - intensity_mae: 0.8147 - loss: 1.3889 - val_emotional_state_accuracy: 0.5417 - val_emotional_state_loss: 1.2398 - val_intensity_loss: 2.7190 - val_intensity_mae: 1.3682 - val_loss: 2.6618 - learning_rate: 3.7500e-05
# Epoch 63/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.6497 - emotional_state_loss: 0.8233 - intensity_loss: 0.9236 - intensity_mae: 0.8043 - loss: 1.3476 - val_emotional_state_accuracy: 0.5292 - val_emotional_state_loss: 1.2345 - val_intensity_loss: 2.7273 - val_intensity_mae: 1.3672 - val_loss: 2.6606 - learning_rate: 1.8750e-05
# Epoch 64/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - emotional_state_accuracy: 0.6500 - emotional_state_loss: 0.8379 - intensity_loss: 0.9579 - intensity_mae: 0.8169 - loss: 1.3794 - val_emotional_state_accuracy: 0.5375 - val_emotional_state_loss: 1.2297 - val_intensity_loss: 2.7256 - val_intensity_mae: 1.3696 - val_loss: 2.6550 - learning_rate: 1.8750e-05
# Epoch 65/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.6477 - emotional_state_loss: 0.8266 - intensity_loss: 0.9300 - intensity_mae: 0.7985 - loss: 1.3541 - val_emotional_state_accuracy: 0.5333 - val_emotional_state_loss: 1.2293 - val_intensity_loss: 2.7174 - val_intensity_mae: 1.3688 - val_loss: 2.6505 - learning_rate: 1.8750e-05
# Epoch 66/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - emotional_state_accuracy: 0.6471 - emotional_state_loss: 0.8217 - intensity_loss: 0.9157 - intensity_mae: 0.7957 - loss: 1.3420 - val_emotional_state_accuracy: 0.5417 - val_emotional_state_loss: 1.2258 - val_intensity_loss: 2.7423 - val_intensity_mae: 1.3711 - val_loss: 2.6595 - learning_rate: 1.8750e-05
# Epoch 67/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - emotional_state_accuracy: 0.6497 - emotional_state_loss: 0.8272 - intensity_loss: 0.9639 - intensity_mae: 0.8168 - loss: 1.3716 - val_emotional_state_accuracy: 0.5333 - val_emotional_state_loss: 1.2183 - val_intensity_loss: 2.7329 - val_intensity_mae: 1.3720 - val_loss: 2.6472 - learning_rate: 1.8750e-05
# Epoch 68/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.6557 - emotional_state_loss: 0.8132 - intensity_loss: 0.9401 - intensity_mae: 0.8039 - loss: 1.3458 - val_emotional_state_accuracy: 0.5250 - val_emotional_state_loss: 1.2133 - val_intensity_loss: 2.6969 - val_intensity_mae: 1.3573 - val_loss: 2.6243 - learning_rate: 1.8750e-05
# Epoch 69/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.6521 - emotional_state_loss: 0.8204 - intensity_loss: 0.9837 - intensity_mae: 0.8187 - loss: 1.3748 - val_emotional_state_accuracy: 0.5333 - val_emotional_state_loss: 1.2280 - val_intensity_loss: 2.7082 - val_intensity_mae: 1.3610 - val_loss: 2.6446 - learning_rate: 1.8750e-05
# Epoch 70/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - emotional_state_accuracy: 0.6536 - emotional_state_loss: 0.8237 - intensity_loss: 0.8907 - intensity_mae: 0.7890 - loss: 1.3315 - val_emotional_state_accuracy: 0.5292 - val_emotional_state_loss: 1.2268 - val_intensity_loss: 2.6936 - val_intensity_mae: 1.3586 - val_loss: 2.6361 - learning_rate: 1.8750e-05
# Epoch 71/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - emotional_state_accuracy: 0.6638 - emotional_state_loss: 0.8008 - intensity_loss: 0.9145 - intensity_mae: 0.8029 - loss: 1.3205 - val_emotional_state_accuracy: 0.5208 - val_emotional_state_loss: 1.2235 - val_intensity_loss: 2.6974 - val_intensity_mae: 1.3608 - val_loss: 2.6346 - learning_rate: 1.8750e-05
# Epoch 72/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.6534 - emotional_state_loss: 0.8140 - intensity_loss: 0.9290 - intensity_mae: 0.8023 - loss: 1.3410 - val_emotional_state_accuracy: 0.5375 - val_emotional_state_loss: 1.2192 - val_intensity_loss: 2.7058 - val_intensity_mae: 1.3617 - val_loss: 2.6346 - learning_rate: 1.8750e-05
# Epoch 73/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.6672 - emotional_state_loss: 0.8244 - intensity_loss: 0.8983 - intensity_mae: 0.7892 - loss: 1.3360 - val_emotional_state_accuracy: 0.5417 - val_emotional_state_loss: 1.2199 - val_intensity_loss: 2.6895 - val_intensity_mae: 1.3625 - val_loss: 2.6271 - learning_rate: 1.8750e-05
# Epoch 74/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.6570 - emotional_state_loss: 0.8152 - intensity_loss: 0.8936 - intensity_mae: 0.7870 - loss: 1.3245 - val_emotional_state_accuracy: 0.5417 - val_emotional_state_loss: 1.2240 - val_intensity_loss: 2.6731 - val_intensity_mae: 1.3529 - val_loss: 2.6230 - learning_rate: 1.8750e-05
# Epoch 75/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.6523 - emotional_state_loss: 0.8154 - intensity_loss: 0.9179 - intensity_mae: 0.7967 - loss: 1.3367 - val_emotional_state_accuracy: 0.5375 - val_emotional_state_loss: 1.2208 - val_intensity_loss: 2.6969 - val_intensity_mae: 1.3607 - val_loss: 2.6317 - learning_rate: 1.8750e-05
# Epoch 76/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.6685 - emotional_state_loss: 0.7816 - intensity_loss: 0.9203 - intensity_mae: 0.8032 - loss: 1.3042 - val_emotional_state_accuracy: 0.5333 - val_emotional_state_loss: 1.2138 - val_intensity_loss: 2.6857 - val_intensity_mae: 1.3568 - val_loss: 2.6191 - learning_rate: 1.8750e-05
# Epoch 77/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.6797 - emotional_state_loss: 0.7742 - intensity_loss: 0.9046 - intensity_mae: 0.7893 - loss: 1.2889 - val_emotional_state_accuracy: 0.5333 - val_emotional_state_loss: 1.2152 - val_intensity_loss: 2.7079 - val_intensity_mae: 1.3602 - val_loss: 2.6316 - learning_rate: 1.8750e-05
# Epoch 78/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - emotional_state_accuracy: 0.6589 - emotional_state_loss: 0.7898 - intensity_loss: 0.9626 - intensity_mae: 0.8151 - loss: 1.3335 - val_emotional_state_accuracy: 0.5333 - val_emotional_state_loss: 1.2138 - val_intensity_loss: 2.7032 - val_intensity_mae: 1.3605 - val_loss: 2.6278 - learning_rate: 1.8750e-05
# Epoch 79/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.6656 - emotional_state_loss: 0.7845 - intensity_loss: 0.9038 - intensity_mae: 0.7903 - loss: 1.2989 - val_emotional_state_accuracy: 0.5250 - val_emotional_state_loss: 1.2266 - val_intensity_loss: 2.7226 - val_intensity_mae: 1.3657 - val_loss: 2.6503 - learning_rate: 1.8750e-05
# Epoch 80/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.6628 - emotional_state_loss: 0.7854 - intensity_loss: 0.9099 - intensity_mae: 0.7995 - loss: 1.3027 - val_emotional_state_accuracy: 0.5417 - val_emotional_state_loss: 1.2143 - val_intensity_loss: 2.6970 - val_intensity_mae: 1.3587 - val_loss: 2.6253 - learning_rate: 1.8750e-05
# Epoch 81/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - emotional_state_accuracy: 0.6630 - emotional_state_loss: 0.7833 - intensity_loss: 0.9145 - intensity_mae: 0.7963 - loss: 1.3029 - val_emotional_state_accuracy: 0.5417 - val_emotional_state_loss: 1.2146 - val_intensity_loss: 2.6994 - val_intensity_mae: 1.3575 - val_loss: 2.6267 - learning_rate: 1.8750e-05
# Epoch 82/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.6651 - emotional_state_loss: 0.7971 - intensity_loss: 0.9028 - intensity_mae: 0.7960 - loss: 1.3110 - val_emotional_state_accuracy: 0.5375 - val_emotional_state_loss: 1.2184 - val_intensity_loss: 2.7197 - val_intensity_mae: 1.3617 - val_loss: 2.6407 - learning_rate: 1.8750e-05
# Epoch 83/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - emotional_state_accuracy: 0.6557 - emotional_state_loss: 0.8224 - intensity_loss: 0.9003 - intensity_mae: 0.7892 - loss: 1.3350 - val_emotional_state_accuracy: 0.5375 - val_emotional_state_loss: 1.2210 - val_intensity_loss: 2.6973 - val_intensity_mae: 1.3604 - val_loss: 2.6321 - learning_rate: 1.8750e-05
# Epoch 84/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.6664 - emotional_state_loss: 0.7931 - intensity_loss: 0.9133 - intensity_mae: 0.7958 - loss: 1.3121 - val_emotional_state_accuracy: 0.5333 - val_emotional_state_loss: 1.2212 - val_intensity_loss: 2.6955 - val_intensity_mae: 1.3606 - val_loss: 2.6313 - learning_rate: 1.8750e-05
# Epoch 85/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - emotional_state_accuracy: 0.6648 - emotional_state_loss: 0.7885 - intensity_loss: 0.8963 - intensity_mae: 0.7837 - loss: 1.2990 - val_emotional_state_accuracy: 0.5375 - val_emotional_state_loss: 1.2250 - val_intensity_loss: 2.7233 - val_intensity_mae: 1.3670 - val_loss: 2.6491 - learning_rate: 1.8750e-05
# Epoch 86/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.6742 - emotional_state_loss: 0.7675 - intensity_loss: 0.8967 - intensity_mae: 0.7875 - loss: 1.2782 - val_emotional_state_accuracy: 0.5500 - val_emotional_state_loss: 1.2165 - val_intensity_loss: 2.6918 - val_intensity_mae: 1.3608 - val_loss: 2.6248 - learning_rate: 1.8750e-05
# Epoch 87/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - emotional_state_accuracy: 0.6750 - emotional_state_loss: 0.7778 - intensity_loss: 0.9300 - intensity_mae: 0.8036 - loss: 1.3053 - val_emotional_state_accuracy: 0.5458 - val_emotional_state_loss: 1.2212 - val_intensity_loss: 2.7166 - val_intensity_mae: 1.3702 - val_loss: 2.6419 - learning_rate: 1.8750e-05
# Epoch 88/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.6742 - emotional_state_loss: 0.7790 - intensity_loss: 0.9001 - intensity_mae: 0.7926 - loss: 1.2915 - val_emotional_state_accuracy: 0.5458 - val_emotional_state_loss: 1.2176 - val_intensity_loss: 2.7217 - val_intensity_mae: 1.3653 - val_loss: 2.6408 - learning_rate: 1.8750e-05
# Epoch 89/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.6828 - emotional_state_loss: 0.7590 - intensity_loss: 0.9074 - intensity_mae: 0.7926 - loss: 1.2751 - val_emotional_state_accuracy: 0.5625 - val_emotional_state_loss: 1.2087 - val_intensity_loss: 2.7062 - val_intensity_mae: 1.3656 - val_loss: 2.6242 - learning_rate: 9.3750e-06
# Epoch 90/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.6677 - emotional_state_loss: 0.7903 - intensity_loss: 0.9061 - intensity_mae: 0.7883 - loss: 1.3057 - val_emotional_state_accuracy: 0.5500 - val_emotional_state_loss: 1.2142 - val_intensity_loss: 2.7024 - val_intensity_mae: 1.3590 - val_loss: 2.6278 - learning_rate: 9.3750e-06
# Epoch 91/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.6641 - emotional_state_loss: 0.7827 - intensity_loss: 0.8932 - intensity_mae: 0.7873 - loss: 1.2917 - val_emotional_state_accuracy: 0.5500 - val_emotional_state_loss: 1.2082 - val_intensity_loss: 2.7268 - val_intensity_mae: 1.3639 - val_loss: 2.6340 - learning_rate: 9.3750e-06
# Epoch 92/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - emotional_state_accuracy: 0.6732 - emotional_state_loss: 0.7737 - intensity_loss: 0.8793 - intensity_mae: 0.7850 - loss: 1.2757 - val_emotional_state_accuracy: 0.5458 - val_emotional_state_loss: 1.2170 - val_intensity_loss: 2.7145 - val_intensity_mae: 1.3666 - val_loss: 2.6366 - learning_rate: 9.3750e-06
# Epoch 93/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - emotional_state_accuracy: 0.6667 - emotional_state_loss: 0.7756 - intensity_loss: 0.9440 - intensity_mae: 0.8062 - loss: 1.3100 - val_emotional_state_accuracy: 0.5542 - val_emotional_state_loss: 1.2126 - val_intensity_loss: 2.7080 - val_intensity_mae: 1.3607 - val_loss: 2.6290 - learning_rate: 9.3750e-06
# Epoch 94/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - emotional_state_accuracy: 0.6719 - emotional_state_loss: 0.7656 - intensity_loss: 0.9094 - intensity_mae: 0.7905 - loss: 1.2827 - val_emotional_state_accuracy: 0.5458 - val_emotional_state_loss: 1.2192 - val_intensity_loss: 2.7186 - val_intensity_mae: 1.3647 - val_loss: 2.6409 - learning_rate: 9.3750e-06
# Epoch 95/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - emotional_state_accuracy: 0.6807 - emotional_state_loss: 0.7607 - intensity_loss: 0.9054 - intensity_mae: 0.7896 - loss: 1.2757 - val_emotional_state_accuracy: 0.5458 - val_emotional_state_loss: 1.2130 - val_intensity_loss: 2.7022 - val_intensity_mae: 1.3577 - val_loss: 2.6265 - learning_rate: 9.3750e-06
# Epoch 96/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - emotional_state_accuracy: 0.6659 - emotional_state_loss: 0.7858 - intensity_loss: 0.9116 - intensity_mae: 0.8011 - loss: 1.3040 - val_emotional_state_accuracy: 0.5417 - val_emotional_state_loss: 1.2185 - val_intensity_loss: 2.7148 - val_intensity_mae: 1.3627 - val_loss: 2.6383 - learning_rate: 9.3750e-06
# Epoch 97/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.6807 - emotional_state_loss: 0.7460 - intensity_loss: 0.8995 - intensity_mae: 0.7896 - loss: 1.2581 - val_emotional_state_accuracy: 0.5542 - val_emotional_state_loss: 1.2171 - val_intensity_loss: 2.7049 - val_intensity_mae: 1.3594 - val_loss: 2.6319 - learning_rate: 9.3750e-06
# Epoch 98/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.6750 - emotional_state_loss: 0.7711 - intensity_loss: 0.8978 - intensity_mae: 0.7869 - loss: 1.2824 - val_emotional_state_accuracy: 0.5500 - val_emotional_state_loss: 1.2088 - val_intensity_loss: 2.7441 - val_intensity_mae: 1.3654 - val_loss: 2.6432 - learning_rate: 9.3750e-06
# Epoch 99/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - emotional_state_accuracy: 0.6802 - emotional_state_loss: 0.7532 - intensity_loss: 0.8858 - intensity_mae: 0.7819 - loss: 1.2585 - val_emotional_state_accuracy: 0.5583 - val_emotional_state_loss: 1.2128 - val_intensity_loss: 2.7066 - val_intensity_mae: 1.3686 - val_loss: 2.6285 - learning_rate: 9.3750e-06
# Epoch 100/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.6622 - emotional_state_loss: 0.7872 - intensity_loss: 0.8876 - intensity_mae: 0.7752 - loss: 1.2934 - val_emotional_state_accuracy: 0.5458 - val_emotional_state_loss: 1.2128 - val_intensity_loss: 2.7241 - val_intensity_mae: 1.3701 - val_loss: 2.6372 - learning_rate: 9.3750e-06
# Epoch 101/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.6656 - emotional_state_loss: 0.7694 - intensity_loss: 0.9149 - intensity_mae: 0.7917 - loss: 1.2892 - val_emotional_state_accuracy: 0.5417 - val_emotional_state_loss: 1.2169 - val_intensity_loss: 2.7230 - val_intensity_mae: 1.3667 - val_loss: 2.6407 - learning_rate: 4.6875e-06
# Epoch 102/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.6784 - emotional_state_loss: 0.7657 - intensity_loss: 0.8904 - intensity_mae: 0.7844 - loss: 1.2733 - val_emotional_state_accuracy: 0.5667 - val_emotional_state_loss: 1.2146 - val_intensity_loss: 2.7118 - val_intensity_mae: 1.3640 - val_loss: 2.6329 - learning_rate: 4.6875e-06
# Epoch 103/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.6862 - emotional_state_loss: 0.7431 - intensity_loss: 0.8763 - intensity_mae: 0.7785 - loss: 1.2436 - val_emotional_state_accuracy: 0.5542 - val_emotional_state_loss: 1.2217 - val_intensity_loss: 2.7353 - val_intensity_mae: 1.3681 - val_loss: 2.6518 - learning_rate: 4.6875e-06
# Epoch 104/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - emotional_state_accuracy: 0.6812 - emotional_state_loss: 0.7519 - intensity_loss: 0.8930 - intensity_mae: 0.7816 - loss: 1.2607 - val_emotional_state_accuracy: 0.5625 - val_emotional_state_loss: 1.2143 - val_intensity_loss: 2.7307 - val_intensity_mae: 1.3701 - val_loss: 2.6420 - learning_rate: 4.6875e-06
# Epoch 105/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.6820 - emotional_state_loss: 0.7593 - intensity_loss: 0.8713 - intensity_mae: 0.7764 - loss: 1.2573 - val_emotional_state_accuracy: 0.5458 - val_emotional_state_loss: 1.2112 - val_intensity_loss: 2.6988 - val_intensity_mae: 1.3619 - val_loss: 2.6230 - learning_rate: 4.6875e-06
# Epoch 106/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.6904 - emotional_state_loss: 0.7480 - intensity_loss: 0.9349 - intensity_mae: 0.7946 - loss: 1.2778 - val_emotional_state_accuracy: 0.5500 - val_emotional_state_loss: 1.2119 - val_intensity_loss: 2.7049 - val_intensity_mae: 1.3640 - val_loss: 2.6267 - learning_rate: 4.6875e-06
# Epoch 107/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - emotional_state_accuracy: 0.6880 - emotional_state_loss: 0.7572 - intensity_loss: 0.8774 - intensity_mae: 0.7779 - loss: 1.2583 - val_emotional_state_accuracy: 0.5500 - val_emotional_state_loss: 1.2156 - val_intensity_loss: 2.6925 - val_intensity_mae: 1.3633 - val_loss: 2.6242 - learning_rate: 4.6875e-06
# Epoch 108/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - emotional_state_accuracy: 0.6820 - emotional_state_loss: 0.7577 - intensity_loss: 0.9246 - intensity_mae: 0.7986 - loss: 1.2824 - val_emotional_state_accuracy: 0.5500 - val_emotional_state_loss: 1.2290 - val_intensity_loss: 2.7195 - val_intensity_mae: 1.3641 - val_loss: 2.6511 - learning_rate: 4.6875e-06
# Epoch 109/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - emotional_state_accuracy: 0.6753 - emotional_state_loss: 0.7670 - intensity_loss: 0.9235 - intensity_mae: 0.7962 - loss: 1.2911 - val_emotional_state_accuracy: 0.5500 - val_emotional_state_loss: 1.2171 - val_intensity_loss: 2.7130 - val_intensity_mae: 1.3648 - val_loss: 2.6360 - learning_rate: 4.6875e-06
# Epoch 110/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - emotional_state_accuracy: 0.6781 - emotional_state_loss: 0.7504 - intensity_loss: 0.9193 - intensity_mae: 0.7908 - loss: 1.2724 - val_emotional_state_accuracy: 0.5583 - val_emotional_state_loss: 1.2119 - val_intensity_loss: 2.7105 - val_intensity_mae: 1.3660 - val_loss: 2.6295 - learning_rate: 4.6875e-06
# Epoch 111/300
# ...
#   Your reflection shows mental clarity and readiness. Your face emotion and stress levels confirm it. This is your peak window — start your most important task right now.
#
#   ID 10045 [OVERWHELMED, intensity=4]
#   You're carrying too much right now. The reflection and emotional signals both point to overload. Rest is not laziness here — it is the strategy. Pick just one small task after a break.
#
#   ID 10046 [FOCUSED, intensity=2]
#   Your reflection shows mental clarity and readiness. Your face emotion and stress levels confirm it. This is your peak window — start your most important task right now.
#
#   ID 10047 [FOCUSED, intensity=3]
#   Your reflection shows mental clarity and readiness. Your face emotion and stress levels confirm it. This is your peak window — start your most important task right now.
#
#   ID 10048 [FOCUSED, intensity=3]
#   Your reflection shows mental clarity and readiness. Your face emotion and stress levels confirm it. This is your peak window — start your most important task right now.
#
#   ID 10049 [OVERWHELMED, intensity=2]
#   You're carrying too much right now. The reflection and emotional signals both point to overload. Rest is not laziness here — it is the strategy. Pick just one small task after a break.
#
#   ID 10050 [RESTLESS, intensity=3]
#   You seem physically or mentally unsettled. Some light movement — a short walk or stretching — can help discharge the restless energy before sitting back down to work.
#
#   ID 10051 [CALM_NEUTRAL, intensity=3]
#   You're in a steady, balanced state. This is a good window for light planning or gentle focused work. Don't push too hard — maintain the calm.
#
#   ID 10052 [OVERWHELMED, intensity=3]
#   You're carrying too much right now. The reflection and emotional signals both point to overload. Rest is not laziness here — it is the strategy. Pick just one small task after a break.
#
#   ID 10053 [FOCUSED, intensity=3]
#   Your reflection shows mental clarity and readiness. Your face emotion and stress levels confirm it. This is your peak window — start your most important task right now.
#
#   ID 10054 [OVERWHELMED, intensity=5]
#   You're carrying too much right now. The reflection and emotional signals both point to overload. Rest is not laziness here — it is the strategy. Pick just one small task after a break.
#
#   ID 10055 [MIXED, intensity=5]
#   Your signals are split — some calm, some tension. Your journal shows conflicting thoughts. A short journaling or light planning session can help you clarify which direction to move.
#
#   ID 10056 [FOCUSED, intensity=4]
#   Your reflection shows mental clarity and readiness. Your face emotion and stress levels confirm it. This is your peak window — start your most important task right now.
#
#   ID 10057 [RESTLESS, intensity=4]
#   You seem physically or mentally unsettled. Some light movement — a short walk or stretching — can help discharge the restless energy before sitting back down to work.
#
#   ID 10058 [OVERWHELMED, intensity=4]
#   You're carrying too much right now. The reflection and emotional signals both point to overload. Rest is not laziness here — it is the strategy. Pick just one small task after a break.
#
#   ID 10059 [OVERWHELMED, intensity=3]
#   You're carrying too much right now. The reflection and emotional signals both point to overload. Rest is not laziness here — it is the strategy. Pick just one small task after a break.
#
#   ID 10060 [OVERWHELMED, intensity=5]
#   You're carrying too much right now. The reflection and emotional signals both point to overload. Rest is not laziness here — it is the strategy. Pick just one small task after a break.
#
#   ID 10061 [CALM_NEUTRAL, intensity=3]
#   You're in a steady, balanced state. This is a good window for light planning or gentle focused work. Don't push too hard — maintain the calm.
#
#   ID 10062 [RESTLESS, intensity=3]
#   You seem physically or mentally unsettled. Some light movement — a short walk or stretching — can help discharge the restless energy before sitting back down to work.
#
#   ID 10063 [RESTLESS, intensity=3]
#   You seem physically or mentally unsettled. Some light movement — a short walk or stretching — can help discharge the restless energy before sitting back down to work.
#
#   ID 10064 [CALM_NEUTRAL, intensity=4]
#   You're in a steady, balanced state. This is a good window for light planning or gentle focused work. Don't push too hard — maintain the calm.
#
#   ID 10065 [FOCUSED, intensity=3]
#   Your reflection shows mental clarity and readiness. Your face emotion and stress levels confirm it. This is your peak window — start your most important task right now.
#
#   ID 10066 [OVERWHELMED, intensity=3]
#   You're carrying too much right now. The reflection and emotional signals both point to overload. Rest is not laziness here — it is the strategy. Pick just one small task after a break.
#
#   ID 10067 [FOCUSED, intensity=3]
#   Your reflection shows mental clarity and readiness. Your face emotion and stress levels confirm it. This is your peak window — start your most important task right now.
#
#   ID 10068 [OVERWHELMED, intensity=4]
#   You're carrying too much right now. The reflection and emotional signals both point to overload. Rest is not laziness here — it is the strategy. Pick just one small task after a break.
#
#   ID 10069 [MIXED, intensity=3]
#   Your signals are split — some calm, some tension. Your journal shows conflicting thoughts. A short journaling or light planning session can help you clarify which direction to move.
#
#   ID 10070 [CALM_NEUTRAL, intensity=3]
#   You're in a steady, balanced state. This is a good window for light planning or gentle focused work. Don't push too hard — maintain the calm.
#
#   ID 10071 [MIXED, intensity=3]
#   Your signals are split — some calm, some tension. Your journal shows conflicting thoughts. A short journaling or light planning session can help you clarify which direction to move.
#
#   ID 10072 [CALM_NEUTRAL, intensity=4]
#   You're in a steady, balanced state. This is a good window for light planning or gentle focused work. Don't push too hard — maintain the calm.
#
#   ID 10073 [RESTLESS, intensity=4]
#   You seem physically or mentally unsettled. Some light movement — a short walk or stretching — can help discharge the restless energy before sitting back down to work.
#
#   ID 10074 [MIXED, intensity=4]
#   Your signals are split — some calm, some tension. Your journal shows conflicting thoughts. A short journaling or light planning session can help you clarify which direction to move.
#
#   ID 10075 [RESTLESS, intensity=3]
#   You seem physically or mentally unsettled. Some light movement — a short walk or stretching — can help discharge the restless energy before sitting back down to work.
#
#   ID 10076 [MIXED, intensity=2]
#   Your signals are split — some calm, some tension. Your journal shows conflicting thoughts. A short journaling or light planning session can help you clarify which direction to move.
#
#   ID 10077 [CALM_NEUTRAL, intensity=2]
#   You're in a steady, balanced state. This is a good window for light planning or gentle focused work. Don't push too hard — maintain the calm.
#
#   ID 10078 [CALM_NEUTRAL, intensity=3]
#   You're in a steady, balanced state. This is a good window for light planning or gentle focused work. Don't push too hard — maintain the calm.
#
#   ID 10079 [RESTLESS, intensity=4]
#   You seem physically or mentally unsettled. Some light movement — a short walk or stretching — can help discharge the restless energy before sitting back down to work.
#
#   ID 10080 [FOCUSED, intensity=3]
#   Your reflection shows mental clarity and readiness. Your face emotion and stress levels confirm it. This is your peak window — start your most important task right now.
#
#   ID 10081 [RESTLESS, intensity=4]
#   You seem physically or mentally unsettled. Some light movement — a short walk or stretching — can help discharge the restless energy before sitting back down to work.
#
#   ID 10082 [CALM_NEUTRAL, intensity=4]
#   You're in a steady, balanced state. This is a good window for light planning or gentle focused work. Don't push too hard — maintain the calm.
#
#   ID 10083 [CALM_NEUTRAL, intensity=4]
#   You're in a steady, balanced state. This is a good window for light planning or gentle focused work. Don't push too hard — maintain the calm.
#
#   ID 10084 [OVERWHELMED, intensity=4]
#   You're carrying too much right now. The reflection and emotional signals both point to overload. Rest is not laziness here — it is the strategy. Pick just one small task after a break.
#
#   ID 10085 [RESTLESS, intensity=2]
#   You seem physically or mentally unsettled. Some light movement — a short walk or stretching — can help discharge the restless energy before sitting back down to work.
#
#   ID 10086 [RESTLESS, intensity=5]
#   You seem physically or mentally unsettled. Some light movement — a short walk or stretching — can help discharge the restless energy before sitting back down to work.
#
#   ID 10087 [MIXED, intensity=3]
#   Your signals are split — some calm, some tension. Your journal shows conflicting thoughts. A short journaling or light planning session can help you clarify which direction to move.
#
#   ID 10088 [FOCUSED, intensity=2]
#   Your reflection shows mental clarity and readiness. Your face emotion and stress levels confirm it. This is your peak window — start your most important task right now.
#
#   ID 10089 [CALM_NEUTRAL, intensity=3]
#   You're in a steady, balanced state. This is a good window for light planning or gentle focused work. Don't push too hard — maintain the calm.
#
#   ID 10090 [MIXED, intensity=3]
#   Your signals are split — some calm, some tension. Your journal shows conflicting thoughts. A short journaling or light planning session can help you clarify which direction to move.
#
#   ID 10091 [FOCUSED, intensity=4]
#   Your reflection shows mental clarity and readiness. Your face emotion and stress levels confirm it. This is your peak window — start your most important task right now.
#
#   ID 10092 [OVERWHELMED, intensity=3]
#   You're carrying too much right now. The reflection and emotional signals both point to overload. Rest is not laziness here — it is the strategy. Pick just one small task after a break.
#
#   ID 10093 [MIXED, intensity=5]
#   Your signals are split — some calm, some tension. Your journal shows conflicting thoughts. A short journaling or light planning session can help you clarify which direction to move.
#
#   ID 10094 [FOCUSED, intensity=4]
#   Your reflection shows mental clarity and readiness. Your face emotion and stress levels confirm it. This is your peak window — start your most important task right now.
#
#   ID 10095 [OVERWHELMED, intensity=2]
#   You're carrying too much right now. The reflection and emotional signals both point to overload. Rest is not laziness here — it is the strategy. Pick just one small task after a break.
#
#   ID 10096 [OVERWHELMED, intensity=4]
#   You're carrying too much right now. The reflection and emotional signals both point to overload. Rest is not laziness here — it is the strategy. Pick just one small task after a break.
#
#   ID 10097 [MIXED, intensity=4]
#   Your signals are split — some calm, some tension. Your journal shows conflicting thoughts. A short journaling or light planning session can help you clarify which direction to move.
#
#   ID 10098 [OVERWHELMED, intensity=3]
#   You're carrying too much right now. The reflection and emotional signals both point to overload. Rest is not laziness here — it is the strategy. Pick just one small task after a break.
#
#   ID 10099 [CALM_NEUTRAL, intensity=2]
#   You're in a steady, balanced state. This is a good window for light planning or gentle focused work. Don't push too hard — maintain the calm.
#
#   ID 10100 [RESTLESS, intensity=4]
#   You seem physically or mentally unsettled. Some light movement — a short walk or stretching — can help discharge the restless energy before sitting back down to work.
#
#   ID 10101 [CALM_NEUTRAL, intensity=3]
#   You're in a steady, balanced state. This is a good window for light planning or gentle focused work. Don't push too hard — maintain the calm.
#
#   ID 10102 [OVERWHELMED, intensity=3]
#   You're carrying too much right now. The reflection and emotional signals both point to overload. Rest is not laziness here — it is the strategy. Pick just one small task after a break.
#
#   ID 10103 [CALM_NEUTRAL, intensity=4]
#   You're in a steady, balanced state. This is a good window for light planning or gentle focused work. Don't push too hard — maintain the calm.
#
#   ID 10104 [RESTLESS, intensity=3]
#   You seem physically or mentally unsettled. Some light movement — a short walk or stretching — can help discharge the restless energy before sitting back down to work.
#
#   ID 10105 [OVERWHELMED, intensity=3]
#   You're carrying too much right now. The reflection and emotional signals both point to overload. Rest is not laziness here — it is the strategy. Pick just one small task after a break.
#
#   ID 10106 [FOCUSED, intensity=2]
#   Your reflection shows mental clarity and readiness. Your face emotion and stress levels confirm it. This is your peak window — start your most important task right now.
#
#   ID 10107 [RESTLESS, intensity=2]
#   You seem physically or mentally unsettled. Some light movement — a short walk or stretching — can help discharge the restless energy before sitting back down to work.
#
#   ID 10108 [MIXED, intensity=5]
#   Your signals are split — some calm, some tension. Your journal shows conflicting thoughts. A short journaling or light planning session can help you clarify which direction to move.
#
#   ID 10109 [CALM_NEUTRAL, intensity=4]
#   You're in a steady, balanced state. This is a good window for light planning or gentle focused work. Don't push too hard — maintain the calm.
#
#   ID 10110 [RESTLESS, intensity=4]
#   You seem physically or mentally unsettled. Some light movement — a short walk or stretching — can help discharge the restless energy before sitting back down to work.
#
#   ID 10111 [MIXED, intensity=3]
#   Your signals are split — some calm, some tension. Your journal shows conflicting thoughts. A short journaling or light planning session can help you clarify which direction to move.
#
#   ID 10112 [MIXED, intensity=3]
#   Your signals are split — some calm, some tension. Your journal shows conflicting thoughts. A short journaling or light planning session can help you clarify which direction to move.
#
#   ID 10113 [OVERWHELMED, intensity=1]
#   You're carrying too much right now. The reflection and emotional signals both point to overload. Rest is not laziness here — it is the strategy. Pick just one small task after a break.
#
#   ID 10114 [RESTLESS, intensity=3]
#   You seem physically or mentally unsettled. Some light movement — a short walk or stretching — can help discharge the restless energy before sitting back down to work.
#
#   ID 10115 [CALM_NEUTRAL, intensity=2]
#   You're in a steady, balanced state. This is a good window for light planning or gentle focused work. Don't push too hard — maintain the calm.
#
#   ID 10116 [OVERWHELMED, intensity=2]
#   You're carrying too much right now. The reflection and emotional signals both point to overload. Rest is not laziness here — it is the strategy. Pick just one small task after a break.
#
#   ID 10117 [RESTLESS, intensity=4]
#   You seem physically or mentally unsettled. Some light movement — a short walk or stretching — can help discharge the restless energy before sitting back down to work.
#
#   ID 10118 [FOCUSED, intensity=2]
#   Your reflection shows mental clarity and readiness. Your face emotion and stress levels confirm it. This is your peak window — start your most important task right now.
#
#   ID 10119 [RESTLESS, intensity=4]
#   You seem physically or mentally unsettled. Some light movement — a short walk or stretching — can help discharge the restless energy before sitting back down to work.
#
#   ID 10120 [RESTLESS, intensity=3]
#   You seem physically or mentally unsettled. Some light movement — a short walk or stretching — can help discharge the restless energy before sitting back down to work.

# %% [markdown]
# <a href="https://colab.research.google.com/github/anamitra-tech/ML-Projects/blob/main/EmotionTracker1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.1.2)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 52.8 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import os, warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model, Input, regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from gensim.models import Word2Vec

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import (classification_report, confusion_matrix,
                              accuracy_score, mean_absolute_error)
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.utils.class_weight import compute_class_weight

tf.random.set_seed(42)
np.random.seed(42)
os.makedirs('outputs', exist_ok=True)

print("=" * 65)
print("  ArvyaX — NN  |  TF-IDF + Embeddings + Relationship Modeling")
print("=" * 65)

# ══════════════════════════════════════════════════════════
# LOAD
# ══════════════════════════════════════════════════════════
train_raw = pd.read_csv('Sample_arvyax_reflective_dataset.xlsx - Dataset_120.csv')
test_raw  = pd.read_csv('arvyax_test_inputs_120.xlsx - Sheet1.csv')
print(f"\n  Train: {len(train_raw)}  |  Test: {len(test_raw)}")

# ══════════════════════════════════════════════════════════
# CONFIG
# ══════════════════════════════════════════════════════════
DROP_COLS    = {'id'}
NUMERIC_COLS = ['duration_min', 'sleep_hours', 'energy_level', 'stress_level']
ORDINAL_COLS = ['time_of_day']
CAT_COLS     = ['previous_day_mood', 'face_emotion_hint', 'ambience_type']
TEXT_COL     = 'journal_text'
EMBED_DIM    = 8
TFIDF_DIM    = 300

# ══════════════════════════════════════════════════════════
# PREPROCESSING
# ══════════════════════════════════════════════════════════
print("\n[1] Preprocessing ...")

for df in [train_raw, test_raw]:
    for c in DROP_COLS:
        if c in df.columns:
            df.drop(columns=[c], inplace=True)

# time_of_day → ordinal
TIME_MAP = {'morning':4,'earlymorning':4,'early_morning':4,
            'afternoon':2,'evening':3,'night':1}
def map_time(v):
    return TIME_MAP.get(str(v).strip().lower().replace(' ',''), 2)

train_raw['time_of_day'] = train_raw['time_of_day'].apply(map_time)
test_raw['time_of_day']  = test_raw['time_of_day'].apply(map_time)

# Numeric NaN → train median
print("  Numeric medians:")
for col in NUMERIC_COLS:
    train_raw[col] = pd.to_numeric(train_raw[col], errors='coerce')
    test_raw[col]  = pd.to_numeric(test_raw[col],  errors='coerce')
    med = train_raw[col].median()
    train_raw[col] = train_raw[col].fillna(med)
    test_raw[col]  = test_raw[col].fillna(med)
    print(f"    {col:15s} = {med:.2f}")

# stress_level → scale 0-1 for relationship branch
stress_max = train_raw['stress_level'].max()
train_raw['stress_norm'] = train_raw['stress_level'] / stress_max
test_raw['stress_norm']  = test_raw['stress_level']  / stress_max

# Categorical NaN → 'neutral'
for col in CAT_COLS:
    train_raw[col] = train_raw[col].fillna('neutral').astype(str).str.strip().str.lower()
    test_raw[col]  = test_raw[col].fillna('neutral').astype(str).str.strip().str.lower()

# reflection_quality → fill + lowercase
if 'reflection_quality' in train_raw.columns:
    train_raw['reflection_quality'] = train_raw['reflection_quality'].fillna('unknown').astype(str).str.strip().str.lower()
# test may not have reflection_quality
if 'reflection_quality' not in test_raw.columns:
    test_raw['reflection_quality'] = 'unknown'
else:
    test_raw['reflection_quality']  = test_raw['reflection_quality'].fillna('unknown').astype(str).str.strip().str.lower()

# Text NaN → 'no reflection'
train_raw[TEXT_COL] = train_raw[TEXT_COL].fillna('no reflection').astype(str)
test_raw[TEXT_COL]  = test_raw[TEXT_COL].fillna('no reflection').astype(str)

# Merge calm+neutral (reduces confusion between near-identical classes)
MERGE_MAP = {'calm': 'calm_neutral', 'neutral': 'calm_neutral'}
train_raw['emotional_state'] = train_raw['emotional_state'].map(
    lambda x: MERGE_MAP.get(str(x).strip().lower(), str(x).strip().lower()))

print(f"\n  Classes after calm+neutral merge:")
for cls, cnt in train_raw['emotional_state'].value_counts().items():
    print(f"    {cls:15s} {cnt:3d} ({cnt/len(train_raw)*100:.1f}%)")

# ══════════════════════════════════════════════════════════
# WORD2VEC — categorical + journal text corpus
# ══════════════════════════════════════════════════════════
print("\n[2] Training Word2Vec ...")

def tokenize(value):
    return str(value).strip().lower().replace(' ','_').split('_')

corpus = []
for col in CAT_COLS + ['reflection_quality']:
    for val in pd.concat([train_raw[col], test_raw[col]]).unique():
        corpus.append(tokenize(val))
for text in train_raw[TEXT_COL]:
    tokens = str(text).lower().split()
    if tokens:
        corpus.append(tokens)

w2v = Word2Vec(sentences=corpus, vector_size=EMBED_DIM,
               window=3, min_count=1, workers=4, seed=42, epochs=100)

def get_emb(value):
    tokens = tokenize(value)
    vecs = [w2v.wv[t] if t in w2v.wv else np.zeros(EMBED_DIM) for t in tokens]
    return np.mean(vecs, axis=0)

def embed_col(series):
    return np.vstack([get_emb(v) for v in series]).astype(np.float32)

print(f"  Vocabulary size: {len(w2v.wv)}")

# ══════════════════════════════════════════════════════════
# TF-IDF on journal_text
# ══════════════════════════════════════════════════════════
print("\n[3] TF-IDF on journal_text ...")

tfidf    = TfidfVectorizer(max_features=TFIDF_DIM, ngram_range=(1,2),
                            sublinear_tf=True, min_df=2, lowercase=True)
tfidf_tr = tfidf.fit_transform(train_raw[TEXT_COL]).toarray().astype(np.float32)
tfidf_te = tfidf.transform(test_raw[TEXT_COL]).toarray().astype(np.float32)
print(f"  TF-IDF shape: {tfidf_tr.shape}")

# ══════════════════════════════════════════════════════════
# BUILD ALL FEATURE ARRAYS
# ══════════════════════════════════════════════════════════
print("\n[4] Building feature arrays ...")

NUM_FEAT  = NUMERIC_COLS + ORDINAL_COLS   # 5 features

scaler    = StandardScaler()
X_num_tr  = scaler.fit_transform(train_raw[NUM_FEAT].values.astype(float)).astype(np.float32)
X_num_te  = scaler.transform(test_raw[NUM_FEAT].values.astype(float)).astype(np.float32)

# stress_level as standalone (for relationship branch)
X_stress_tr = train_raw['stress_norm'].values.astype(np.float32).reshape(-1,1)
X_stress_te = test_raw['stress_norm'].values.astype(np.float32).reshape(-1,1)

# Word2Vec embeddings for categorical cols
mood_emb_tr = embed_col(train_raw['previous_day_mood'])
mood_emb_te = embed_col(test_raw['previous_day_mood'])

emo_emb_tr  = embed_col(train_raw['face_emotion_hint'])   # used in relationship branch
emo_emb_te  = embed_col(test_raw['face_emotion_hint'])

amb_emb_tr  = embed_col(train_raw['ambience_type'])
amb_emb_te  = embed_col(test_raw['ambience_type'])

rq_emb_tr   = embed_col(train_raw['reflection_quality'])  # used in relationship branch
rq_emb_te   = embed_col(test_raw['reflection_quality'])

print(f"  TF-IDF       : {tfidf_tr.shape[1]}")
print(f"  Numeric      : {X_num_tr.shape[1]}")
print(f"  Stress       : 1  (relationship branch)")
print(f"  face_emotion : {emo_emb_tr.shape[1]}  (relationship branch)")
print(f"  refl_quality : {rq_emb_tr.shape[1]}  (relationship branch)")
print(f"  mood_emb     : {mood_emb_tr.shape[1]}")
print(f"  ambience_emb : {amb_emb_tr.shape[1]}")

# ══════════════════════════════════════════════════════════
# TARGETS
# ══════════════════════════════════════════════════════════
print("\n[5] Encoding targets ...")

le_state = LabelEncoder()
y_state  = le_state.fit_transform(train_raw['emotional_state'])
y_intens = train_raw['intensity'].fillna(2).astype(float).values  # regression target

N_CLASSES = len(le_state.classes_)
print(f"  Y1 classes ({N_CLASSES}): {list(le_state.classes_)}")
print(f"  Y2 intensity range: {y_intens.min():.0f} – {y_intens.max():.0f}")

# Class weights for Y1
cw_arr  = compute_class_weight('balanced', classes=np.unique(y_state), y=y_state)
cw_dict = dict(enumerate(cw_arr))
sample_w = np.array([cw_dict[c] for c in y_state], dtype=np.float32)

# ══════════════════════════════════════════════════════════
# TRAIN / VAL SPLIT  80 / 20
# ══════════════════════════════════════════════════════════
print("\n[6] Train/Val split 80/20 ...")

tr_i, val_i = train_test_split(
    np.arange(len(train_raw)), test_size=0.2,
    random_state=42, stratify=y_state)

def sp(a): return a[tr_i], a[val_i]

Xtf_tr,  Xtf_val  = sp(tfidf_tr)
Xnum_tr, Xnum_val = sp(X_num_tr)
Xstr_tr, Xstr_val = sp(X_stress_tr)
Xemo_tr, Xemo_val = sp(emo_emb_tr)
Xrq_tr,  Xrq_val  = sp(rq_emb_tr)
Xmood_tr,Xmood_val= sp(mood_emb_tr)
Xamb_tr, Xamb_val = sp(amb_emb_tr)

ys_tr, ys_val = sp(y_state)
yi_tr, yi_val = sp(y_intens)
sw_tr         = sample_w[tr_i]

print(f"  Train:{len(tr_i)}  Val:{len(val_i)}  Test:{len(test_raw)}")

# ══════════════════════════════════════════════════════════
# DATA AUGMENTATION — Gaussian noise on numeric + tfidf
# ══════════════════════════════════════════════════════════
def augment_all(arrays_list, ys, yi, sw, n=3, noise=0.06):
    aug = [list(arrays_list)]
    ya, yia, swa = [ys], [yi], [sw]
    for _ in range(n):
        noisy = []
        for arr in arrays_list:
            n_arr = arr + np.random.normal(0, noise, arr.shape).astype(np.float32)
            noisy.append(n_arr)
        aug.append(noisy)
        ya.append(ys); yia.append(yi); swa.append(sw)
    stacked = [np.vstack([a[i] for a in aug]) for i in range(len(arrays_list))]
    return stacked, np.concatenate(ya), np.concatenate(yia), np.concatenate(swa)

train_arrays = [Xtf_tr, Xnum_tr, Xstr_tr, Xemo_tr, Xrq_tr, Xmood_tr, Xamb_tr]
aug_arrays, ys_aug, yi_aug, _ = augment_all(train_arrays, ys_tr, yi_tr, sw_tr)
Xtf_aug, Xnum_aug, Xstr_aug, Xemo_aug, Xrq_aug, Xmood_aug, Xamb_aug = aug_arrays

print(f"\n  After augmentation: {len(ys_aug)} samples (was {len(ys_tr)})")

# ══════════════════════════════════════════════════════════
# NEURAL NETWORK  — Multi-Input Multi-Output
# ══════════════════════════════════════════════════════════
print("\n[7] Building Neural Network ...")

L2 = 1e-4

def build_model():
    reg = regularizers.l2(L2)

    # ── INPUT 1: TF-IDF journal_text (300-dim) ──
    tfidf_in  = Input(shape=(TFIDF_DIM,), name='tfidf')
    x_text    = layers.Dense(128, activation='relu', kernel_regularizer=reg)(tfidf_in)
    x_text    = layers.BatchNormalization()(x_text)
    x_text    = layers.Dropout(0.2)(x_text)
    x_text    = layers.Dense(64, activation='relu', kernel_regularizer=reg)(x_text)
    # Branch A output: 64-dim text representation

    # ── INPUT 2: stress_level (1-dim scalar) ──
    stress_in = Input(shape=(1,), name='stress')

    # ── INPUT 3: face_emotion_hint Word2Vec (8-dim) ──
    emo_in    = Input(shape=(EMBED_DIM,), name='face_emotion')

    # ── INPUT 4: reflection_quality Word2Vec (8-dim) ──
    rq_in     = Input(shape=(EMBED_DIM,), name='refl_quality')

    # ── RELATIONSHIP BRANCH ──
    # Models the relationship between stress_level,
    # face_emotion_hint, journal_text and reflection_quality
    rel_concat = layers.Concatenate(name='relationship_inputs')(
        [x_text, stress_in, emo_in, rq_in])   # 64+1+8+8 = 81
    x_rel = layers.Dense(64, activation='relu',
                          kernel_regularizer=reg, name='rel_dense1')(rel_concat)
    x_rel = layers.BatchNormalization()(x_rel)
    x_rel = layers.Dropout(0.15)(x_rel)
    x_rel = layers.Dense(32, activation='relu',
                          kernel_regularizer=reg, name='rel_dense2')(x_rel)
    # Branch B output: 32-dim relationship representation

    # ── INPUT 5: other numeric + ordinal (5-dim) ──
    num_in    = Input(shape=(len(NUM_FEAT),), name='numeric')
    x_num     = layers.Dense(32, activation='relu', kernel_regularizer=reg)(num_in)
    x_num     = layers.BatchNormalization()(x_num)
    x_num     = layers.Dropout(0.1)(x_num)
    x_num     = layers.Dense(16, activation='relu', kernel_regularizer=reg)(x_num)
    # Branch C output: 16-dim numeric representation

    # ── INPUT 6: previous_day_mood (8-dim) ──
    mood_in   = Input(shape=(EMBED_DIM,), name='mood')

    # ── INPUT 7: ambience_type (8-dim) ──
    amb_in    = Input(shape=(EMBED_DIM,), name='ambience')

    # ── MERGE ALL BRANCHES ──
    # 64(text) + 32(relationship) + 16(numeric) + 8(mood) + 8(ambience) = 128
    # Note: stress, face_emotion, refl_quality already consumed in relationship branch
    merged = layers.Concatenate(name='all_merged')(
        [x_text, x_rel, x_num, mood_in, amb_in])

    # ── SHARED HIDDEN ──
    h = layers.Dense(64, activation='relu', kernel_regularizer=reg)(merged)
    h = layers.BatchNormalization()(h)
    h = layers.Dropout(0.15)(h)
    h = layers.Dense(32, activation='relu', kernel_regularizer=reg)(h)
    h = layers.BatchNormalization()(h)
    h = layers.Dropout(0.1)(h)

    # ── HEAD 1: emotional_state → Classification (Softmax) ──
    h1 = layers.Dense(32, activation='relu',
                       kernel_regularizer=reg, name='state_head')(h)
    h1 = layers.Dropout(0.1)(h1)
    out_state = layers.Dense(N_CLASSES, activation='softmax',
                              name='emotional_state')(h1)

    # ── HEAD 2: intensity → Regression (Linear) ──
    h2 = layers.Dense(16, activation='relu',
                       kernel_regularizer=reg, name='intensity_head')(h)
    out_intens = layers.Dense(1, activation='linear',
                               name='intensity')(h2)

    model = Model(
        inputs  = [tfidf_in, num_in, stress_in, emo_in, rq_in, mood_in, amb_in],
        outputs = [out_state, out_intens],
        name    = 'ArvyaX_MultiInput'
    )
    return model

model = build_model()

model.compile(
    optimizer = keras.optimizers.Adam(learning_rate=3e-4),
    loss = {
        'emotional_state': 'sparse_categorical_crossentropy',
        'intensity':        'mse',
    },
    loss_weights = {'emotional_state': 1.0, 'intensity': 0.5},
    metrics = {
        'emotional_state': ['accuracy'],
        'intensity':        ['mae'],
    }
)

model.summary()

# ══════════════════════════════════════════════════════════
# PREPARE INPUT DICTS
# ══════════════════════════════════════════════════════════
def make_inputs(tf, num, stress, emo, rq, mood, amb):
    return {
        'tfidf':        tf,
        'numeric':      num,
        'stress':       stress,
        'face_emotion': emo,
        'refl_quality': rq,
        'mood':         mood,
        'ambience':     amb,
    }

X_train_in = make_inputs(Xtf_aug, Xnum_aug, Xstr_aug,
                          Xemo_aug, Xrq_aug, Xmood_aug, Xamb_aug)
X_val_in   = make_inputs(Xtf_val, Xnum_val, Xstr_val,
                          Xemo_val, Xrq_val, Xmood_val, Xamb_val)
X_test_in  = make_inputs(tfidf_te, X_num_te, X_stress_te,
                          emo_emb_te, rq_emb_te, mood_emb_te, amb_emb_te)

Y_train    = {'emotional_state': ys_aug, 'intensity': yi_aug}
Y_val      = {'emotional_state': ys_val, 'intensity': yi_val}

# ══════════════════════════════════════════════════════════
# TRAIN
# ══════════════════════════════════════════════════════════
print("\n[8] Training ...")

callbacks = [
    EarlyStopping(monitor='val_emotional_state_accuracy', mode='max',
                  patience=30, restore_best_weights=True, verbose=0),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                      patience=12, min_lr=1e-6, verbose=0),
]


# ── Compute per-sample weights from class weights (augmented data) ──
# Keras 3.x does NOT support class_weight or sample_weight dict
# for multi-output models. Workaround: build a tf.data.Dataset
# that bundles (inputs, outputs, sample_weights) as a single tuple.
sw_aug_arr = np.array([cw_dict[c] for c in ys_aug], dtype=np.float32)

import tensorflow as _tf

def make_dataset(x_dict, y_dict, sw, batch_size, shuffle=False):
    ds = _tf.data.Dataset.from_tensor_slices((x_dict, y_dict, sw))
    if shuffle:
        ds = ds.shuffle(len(sw), seed=42)
    return ds.batch(batch_size).prefetch(_tf.data.AUTOTUNE)

BATCH = 8
train_ds = make_dataset(X_train_in, Y_train, sw_aug_arr,    BATCH, shuffle=True)
val_ds   = make_dataset(X_val_in,   Y_val,
                        np.ones(len(ys_val), dtype=np.float32), BATCH)

history = model.fit(
    train_ds,
    validation_data = val_ds,
    epochs          = 300,
    callbacks       = callbacks,
    verbose         = 1,
)

# ══════════════════════════════════════════════════════════
# EVALUATE
# ══════════════════════════════════════════════════════════
print("\n[9] Validation results ...")

val_preds   = model.predict(X_val_in, verbose=0)
ys_pred     = np.argmax(val_preds[0], axis=1)
yi_pred_raw = val_preds[1].flatten()
yi_pred_r   = np.clip(np.round(yi_pred_raw), 1, 5).astype(int)

s_acc = accuracy_score(ys_val, ys_pred)
mae   = mean_absolute_error(yi_val, yi_pred_raw)

print(f"\n  ── Y1: Emotional State (acc={s_acc:.3f}) ──")
print(classification_report(
    le_state.inverse_transform(ys_val),
    le_state.inverse_transform(ys_pred),
    zero_division=0))

print(f"\n  ── Y2: Intensity Regression (MAE={mae:.3f}) ──")
print(f"  True   : {yi_val[:10].astype(int).tolist()}")
print(f"  Pred   : {yi_pred_r[:10].tolist()}")

# ══════════════════════════════════════════════════════════
# PLOTS
# ══════════════════════════════════════════════════════════
print("\n[10] Saving plots ...")

# Training curves
h  = history.history
fig, axes = plt.subplots(2, 2, figsize=(13, 9))
def plot_h(ax, key, title):
    ax.plot(h.get(key,[]),        label='train', color='#534AB7', lw=2)
    ax.plot(h.get('val_'+key,[]), label='val',   color='#993C1D', lw=2, ls='--')
    ax.set_title(title); ax.set_xlabel('Epoch'); ax.legend(); ax.grid(alpha=0.3)

plot_h(axes[0,0], 'emotional_state_accuracy', 'Y1 Accuracy')
plot_h(axes[0,1], 'intensity_mae',             'Y2 MAE')
plot_h(axes[1,0], 'emotional_state_loss',      'Y1 Loss')
plot_h(axes[1,1], 'loss',                      'Total Loss')
plt.tight_layout()
plt.savefig('outputs/01_training_curves.png', dpi=120, bbox_inches='tight')
plt.close()

# Confusion matrix + intensity scatter
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
cm = confusion_matrix(ys_val, ys_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=le_state.classes_,
            yticklabels=le_state.classes_, ax=axes[0])
axes[0].set_title(f'Y1 Emotional State  (acc={s_acc:.2f})')
axes[0].set_xlabel('Predicted'); axes[0].set_ylabel('True')

axes[1].scatter(yi_val, yi_pred_raw, alpha=0.6, color='#534AB7', s=60)
axes[1].plot([1,5],[1,5],'r--', lw=1.5, label='perfect')
axes[1].set_xlabel('True Intensity'); axes[1].set_ylabel('Predicted (continuous)')
axes[1].set_title(f'Y2 Intensity Regression  (MAE={mae:.2f})')
axes[1].legend(); axes[1].grid(alpha=0.3)
plt.tight_layout()
plt.savefig('outputs/02_results.png', dpi=120, bbox_inches='tight')
plt.close()

# Architecture diagram (text-based visual)
fig, ax = plt.subplots(figsize=(12, 7))
ax.axis('off')
arch_text = (
    "Neural Network Architecture\n\n"
    "  INPUT 1: journal_text → TF-IDF(300) → Dense(128→64)  [Branch A: Text]\n"
    "                                                  ↓\n"
    "  INPUT 2: stress_level ──────────────────────────┤\n"
    "  INPUT 3: face_emotion_hint → Word2Vec(8) ────────┤→ Dense(64→32)  [RELATIONSHIP BRANCH]\n"
    "  INPUT 4: reflection_quality → Word2Vec(8) ────────┘  (models stress×emotion×text×quality)\n\n"
    "  INPUT 5: numeric/ordinal(5) → Dense(32→16)  [Branch C: Metadata]\n"
    "  INPUT 6: previous_day_mood → Word2Vec(8)\n"
    "  INPUT 7: ambience_type → Word2Vec(8)\n\n"
    "  ALL MERGED → Dense(64→32) [Shared Hidden]\n"
    "       ├──→ Dense(32→N) + Softmax  ═══ Y1: emotional_state  [CLASSIFICATION]\n"
    "       └──→ Dense(16→1) + Linear   ═══ Y2: intensity        [REGRESSION]\n\n"
    f"  Y1 Classes: {list(le_state.classes_)}\n"
    f"  Y2 Output : continuous 1.0–5.0  (rounded for display)\n"
)
ax.text(0.02, 0.95, arch_text, transform=ax.transAxes,
        fontsize=10, verticalalignment='top', fontfamily='monospace',
        bbox=dict(boxstyle='round', facecolor='#f0f0f0', alpha=0.8))
plt.tight_layout()
plt.savefig('outputs/03_architecture.png', dpi=120, bbox_inches='tight')
plt.close()

print("  Plots saved.")

# ══════════════════════════════════════════════════════════
# UNCERTAINTY
# ══════════════════════════════════════════════════════════
def get_confidence(proba):
    p = np.sort(proba)[::-1]
    conf   = float(p[0])
    margin = float(p[0]-p[1]) if len(p)>1 else 1.0
    return round(conf, 3), int(conf < 0.50 or margin < 0.15)

# ══════════════════════════════════════════════════════════
# RECOMMENDATION ENGINE
# Built from: predicted_state + intensity + stress + energy + time
# ══════════════════════════════════════════════════════════
ACTIVITY_MAP = {
    # (state, high_stress, low_energy) → activity
    ('anxious',      True,  True):  'box_breathing',
    ('anxious',      True,  False): 'box_breathing',
    ('anxious',      False, True):  'rest',
    ('anxious',      False, False): 'grounding',
    ('mixed',        True,  False): 'journaling',
    ('mixed',        False, False): 'light_planning',
    ('calm_neutral', False, False): 'light_planning',
    ('calm_neutral', True,  False): 'grounding',
    ('overwhelmed',  True,  False): 'box_breathing',
    ('overwhelmed',  False, False): 'rest',
    ('focused',      False, False): 'deep_work',
    ('focused',      True,  False): 'yoga',
    ('restless',     True,  False): 'grounding',
    ('restless',     False, False): 'movement',
}

WHEN_MAP = {
    # (state, rounded_intensity) → timing
    ('anxious',      5): 'now',
    ('anxious',      4): 'now',
    ('anxious',      3): 'within_15_min',
    ('anxious',      2): 'within_15_min',
    ('overwhelmed',  5): 'now',
    ('overwhelmed',  4): 'now',
    ('overwhelmed',  3): 'within_15_min',
    ('mixed',        4): 'within_15_min',
    ('mixed',        3): 'within_15_min',
    ('mixed',        2): 'later_today',
    ('restless',     4): 'within_15_min',
    ('restless',     3): 'within_15_min',
    ('calm_neutral', 2): 'later_today',
    ('calm_neutral', 1): 'tomorrow_morning',
    ('focused',      3): 'now',
    ('focused',      2): 'now',
    ('focused',      1): 'later_today',
}

MESSAGES = {
    'anxious':
        "Your reflection shows tension and inner noise. Before anything else, "
        "try 4 rounds of box breathing (4 counts in → hold → out → hold). "
        "Let the stress release before you plan your next step.",

    'overwhelmed':
        "You're carrying too much right now. The reflection and emotional signals "
        "both point to overload. Rest is not laziness here — it is the strategy. "
        "Pick just one small task after a break.",

    'mixed':
        "Your signals are split — some calm, some tension. Your journal shows "
        "conflicting thoughts. A short journaling or light planning session can "
        "help you clarify which direction to move.",

    'calm_neutral':
        "You're in a steady, balanced state. This is a good window for light "
        "planning or gentle focused work. Don't push too hard — maintain the calm.",

    'focused':
        "Your reflection shows mental clarity and readiness. Your face emotion "
        "and stress levels confirm it. This is your peak window — start your "
        "most important task right now.",

    'restless':
        "You seem physically or mentally unsettled. Some light movement — a short "
        "walk or stretching — can help discharge the restless energy before "
        "sitting back down to work.",
}

def decide_what(state, hs, lef):
    for k in [(state,hs,lef),(state,False,lef),(state,False,False)]:
        if k in ACTIVITY_MAP: return ACTIVITY_MAP[k]
    return 'pause'

def decide_when(state, intensity_rounded):
    for k in [(state, intensity_rounded),(state, 2)]:
        if k in WHEN_MAP: return WHEN_MAP[k]
    return 'later_today'

# ══════════════════════════════════════════════════════════
# TEST PREDICTIONS
# ══════════════════════════════════════════════════════════
print("\n[11] Generating test predictions ...")

te_preds    = model.predict(X_test_in, verbose=0)
s_probas    = te_preds[0]
yi_te_raw   = te_preds[1].flatten()
te_states   = le_state.inverse_transform(np.argmax(s_probas, axis=1))
te_intens_r = np.clip(np.round(yi_te_raw), 1, 5).astype(int)

records = []
for i in range(len(test_raw)):
    state     = te_states[i]
    intensity = int(te_intens_r[i])
    conf, unc = get_confidence(s_probas[i])

    stress_val = float(test_raw.iloc[i]['stress_level'])
    energy_val = float(test_raw.iloc[i]['energy_level'])
    hs  = stress_val >= 4
    lef = energy_val <= 2

    what    = decide_what(state, hs, lef)
    when    = decide_when(state, intensity)
    message = MESSAGES.get(state, "Take a moment to pause and check in.")

    records.append({
        'id':                  test_raw.iloc[i]['id'],
        'predicted_state':     state,
        'predicted_intensity': intensity,
        'intensity_raw':       round(float(yi_te_raw[i]), 2),
        'confidence':          conf,
        'uncertain_flag':      unc,
        'what_to_do':          what,
        'when_to_do':          when,
        'supportive_message':  message,
    })

pred_df = pd.DataFrame(records)

print("\n  ── Test Predictions ──")
print(pred_df[['id','predicted_state','predicted_intensity',
               'confidence','uncertain_flag','what_to_do','when_to_do']].to_string(index=False))

print("\n  ── Supportive Messages ──")
for _, r in pred_df.iterrows():
    print(f"\n  ID {r['id']} [{r['predicted_state'].upper()}, intensity={r['predicted_intensity']}]")
    print(f"  {r['supportive_message']}")

# Save
pred_df[['id','predicted_state','predicted_intensity',
         'confidence','uncertain_flag','what_to_do','when_to_do']].to_csv(
    'outputs/predictions.csv', index=False)
pred_df.to_csv('outputs/predictions_full.csv', index=False)
# Out:
# =================================================================
#   ArvyaX — NN  |  TF-IDF + Embeddings + Relationship Modeling
# =================================================================
#
#   Train: 1200  |  Test: 120
#
# [1] Preprocessing ...
#   Numeric medians:
#     duration_min    = 15.00
#     sleep_hours     = 6.00
#     energy_level    = 3.00
#     stress_level    = 3.00
#
#   Classes after calm+neutral merge:
#     calm_neutral    417 (34.8%)
#     restless        209 (17.4%)
#     focused         193 (16.1%)
#     mixed           191 (15.9%)
#     overwhelmed     190 (15.8%)
#
# [2] Training Word2Vec ...
#   Vocabulary size: 517
#
# [3] TF-IDF on journal_text ...
#   TF-IDF shape: (1200, 300)
#
# [4] Building feature arrays ...
#   TF-IDF       : 300
#   Numeric      : 5
#   Stress       : 1  (relationship branch)
#   face_emotion : 8  (relationship branch)
#   refl_quality : 8  (relationship branch)
#   mood_emb     : 8
#   ambience_emb : 8
#
# [5] Encoding targets ...
#   Y1 classes (5): ['calm_neutral', 'focused', 'mixed', 'overwhelmed', 'restless']
#   Y2 intensity range: 1 – 5
#
# [6] Train/Val split 80/20 ...
#   Train:960  Val:240  Test:120
#
#   After augmentation: 3840 samples (was 960)
#
# [7] Building Neural Network ...
# Model: "ArvyaX_MultiInput"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ tfidf (InputLayer)  │ (None, 300)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │     38,528 │ tfidf[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128)       │        512 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stress (InputLayer) │ (None, 1)         │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ face_emotion        │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ refl_quality        │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ relationship_inputs │ (None, 81)        │          0 │ dense_1[0][0],    │
# │ (Concatenate)       │                   │            │ stress[0][0],     │
# │                     │                   │            │ face_emotion[0][… │
# │                     │                   │            │ refl_quality[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ numeric             │ (None, 5)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rel_dense1 (Dense)  │ (None, 64)        │      5,248 │ relationship_inp… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 32)        │        192 │ numeric[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ rel_dense1[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32)        │        128 │ dense_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rel_dense2 (Dense)  │ (None, 32)        │      2,080 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 16)        │        528 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mood (InputLayer)   │ (None, 8)         │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ambience            │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ all_merged          │ (None, 128)       │          0 │ dense_1[0][0],    │
# │ (Concatenate)       │                   │            │ rel_dense2[0][0], │
# │                     │                   │            │ dense_3[0][0],    │
# │                     │                   │            │ mood[0][0],       │
# │                     │                   │            │ ambience[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 64)        │      8,256 │ all_merged[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 64)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 32)        │      2,080 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32)        │        128 │ dense_5[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 32)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ state_head (Dense)  │ (None, 32)        │      1,056 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 32)        │          0 │ state_head[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ intensity_head      │ (None, 16)        │        528 │ dropout_4[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ emotional_state     │ (None, 5)         │        165 │ dropout_5[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ intensity (Dense)   │ (None, 1)         │         17 │ intensity_head[0… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 68,214 (266.46 KB)
#  Trainable params: 67,574 (263.96 KB)
#  Non-trainable params: 640 (2.50 KB)
# [8] Training ...
# Epoch 1/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 17s 6ms/step - emotional_state_accuracy: 0.2268 - emotional_state_loss: 1.7835 - intensity_loss: 9.8380 - intensity_mae: 2.7010 - loss: 6.7617 - val_emotional_state_accuracy: 0.2500 - val_emotional_state_loss: 1.6379 - val_intensity_loss: 3.8403 - val_intensity_mae: 1.5822 - val_loss: 3.6174 - learning_rate: 3.0000e-04
# Epoch 2/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.2167 - emotional_state_loss: 1.6979 - intensity_loss: 3.5054 - intensity_mae: 1.5559 - loss: 3.5100 - val_emotional_state_accuracy: 0.2417 - val_emotional_state_loss: 1.6351 - val_intensity_loss: 2.4743 - val_intensity_mae: 1.3023 - val_loss: 2.9317 - learning_rate: 3.0000e-04
# Epoch 3/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - emotional_state_accuracy: 0.2339 - emotional_state_loss: 1.6604 - intensity_loss: 2.5326 - intensity_mae: 1.3373 - loss: 2.9863 - val_emotional_state_accuracy: 0.2083 - val_emotional_state_loss: 1.6449 - val_intensity_loss: 2.3911 - val_intensity_mae: 1.2894 - val_loss: 2.9000 - learning_rate: 3.0000e-04
# Epoch 4/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.2432 - emotional_state_loss: 1.6452 - intensity_loss: 2.3011 - intensity_mae: 1.2805 - loss: 2.8552 - val_emotional_state_accuracy: 0.2000 - val_emotional_state_loss: 1.6283 - val_intensity_loss: 2.2641 - val_intensity_mae: 1.2590 - val_loss: 2.8199 - learning_rate: 3.0000e-04
# Epoch 5/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.2398 - emotional_state_loss: 1.6332 - intensity_loss: 2.1996 - intensity_mae: 1.2523 - loss: 2.7926 - val_emotional_state_accuracy: 0.1958 - val_emotional_state_loss: 1.6374 - val_intensity_loss: 2.1977 - val_intensity_mae: 1.2465 - val_loss: 2.7959 - learning_rate: 3.0000e-04
# Epoch 6/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.2424 - emotional_state_loss: 1.6259 - intensity_loss: 2.0817 - intensity_mae: 1.2332 - loss: 2.7263 - val_emotional_state_accuracy: 0.2083 - val_emotional_state_loss: 1.6329 - val_intensity_loss: 2.2054 - val_intensity_mae: 1.2515 - val_loss: 2.7952 - learning_rate: 3.0000e-04
# Epoch 7/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.2443 - emotional_state_loss: 1.6132 - intensity_loss: 2.0441 - intensity_mae: 1.2227 - loss: 2.6950 - val_emotional_state_accuracy: 0.2167 - val_emotional_state_loss: 1.6177 - val_intensity_loss: 2.1840 - val_intensity_mae: 1.2574 - val_loss: 2.7694 - learning_rate: 3.0000e-04
# Epoch 8/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - emotional_state_accuracy: 0.2503 - emotional_state_loss: 1.6019 - intensity_loss: 1.9785 - intensity_mae: 1.2051 - loss: 2.6509 - val_emotional_state_accuracy: 0.2125 - val_emotional_state_loss: 1.6042 - val_intensity_loss: 2.1686 - val_intensity_mae: 1.2519 - val_loss: 2.7483 - learning_rate: 3.0000e-04
# Epoch 9/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.2768 - emotional_state_loss: 1.5847 - intensity_loss: 1.9498 - intensity_mae: 1.1988 - loss: 2.6194 - val_emotional_state_accuracy: 0.2583 - val_emotional_state_loss: 1.5857 - val_intensity_loss: 2.1522 - val_intensity_mae: 1.2492 - val_loss: 2.7217 - learning_rate: 3.0000e-04
# Epoch 10/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.2721 - emotional_state_loss: 1.5688 - intensity_loss: 1.9007 - intensity_mae: 1.1815 - loss: 2.5791 - val_emotional_state_accuracy: 0.2667 - val_emotional_state_loss: 1.5818 - val_intensity_loss: 2.2224 - val_intensity_mae: 1.2565 - val_loss: 2.7530 - learning_rate: 3.0000e-04
# Epoch 11/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.2841 - emotional_state_loss: 1.5538 - intensity_loss: 1.8458 - intensity_mae: 1.1677 - loss: 2.5367 - val_emotional_state_accuracy: 0.2958 - val_emotional_state_loss: 1.5712 - val_intensity_loss: 2.1973 - val_intensity_mae: 1.2510 - val_loss: 2.7299 - learning_rate: 3.0000e-04
# Epoch 12/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.3089 - emotional_state_loss: 1.5380 - intensity_loss: 1.8258 - intensity_mae: 1.1554 - loss: 2.5111 - val_emotional_state_accuracy: 0.2792 - val_emotional_state_loss: 1.5780 - val_intensity_loss: 2.2621 - val_intensity_mae: 1.2670 - val_loss: 2.7693 - learning_rate: 3.0000e-04
# Epoch 13/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.3083 - emotional_state_loss: 1.5248 - intensity_loss: 1.8033 - intensity_mae: 1.1535 - loss: 2.4867 - val_emotional_state_accuracy: 0.2958 - val_emotional_state_loss: 1.5622 - val_intensity_loss: 2.2305 - val_intensity_mae: 1.2539 - val_loss: 2.7378 - learning_rate: 3.0000e-04
# Epoch 14/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.3260 - emotional_state_loss: 1.5156 - intensity_loss: 1.7628 - intensity_mae: 1.1384 - loss: 2.4574 - val_emotional_state_accuracy: 0.3042 - val_emotional_state_loss: 1.5556 - val_intensity_loss: 2.2585 - val_intensity_mae: 1.2584 - val_loss: 2.7454 - learning_rate: 3.0000e-04
# Epoch 15/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.3424 - emotional_state_loss: 1.4797 - intensity_loss: 1.7358 - intensity_mae: 1.1206 - loss: 2.4082 - val_emotional_state_accuracy: 0.3208 - val_emotional_state_loss: 1.5503 - val_intensity_loss: 2.2824 - val_intensity_mae: 1.2579 - val_loss: 2.7522 - learning_rate: 3.0000e-04
# Epoch 16/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.3508 - emotional_state_loss: 1.4479 - intensity_loss: 1.6822 - intensity_mae: 1.1111 - loss: 2.3498 - val_emotional_state_accuracy: 0.3625 - val_emotional_state_loss: 1.5082 - val_intensity_loss: 2.3594 - val_intensity_mae: 1.2938 - val_loss: 2.7488 - learning_rate: 3.0000e-04
# Epoch 17/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.3781 - emotional_state_loss: 1.4236 - intensity_loss: 1.6331 - intensity_mae: 1.0923 - loss: 2.3011 - val_emotional_state_accuracy: 0.3667 - val_emotional_state_loss: 1.4831 - val_intensity_loss: 2.3259 - val_intensity_mae: 1.2904 - val_loss: 2.7071 - learning_rate: 3.0000e-04
# Epoch 18/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.3971 - emotional_state_loss: 1.3838 - intensity_loss: 1.6279 - intensity_mae: 1.0983 - loss: 2.2589 - val_emotional_state_accuracy: 0.3792 - val_emotional_state_loss: 1.4863 - val_intensity_loss: 2.3880 - val_intensity_mae: 1.2992 - val_loss: 2.7415 - learning_rate: 3.0000e-04
# Epoch 19/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.4031 - emotional_state_loss: 1.3738 - intensity_loss: 1.5594 - intensity_mae: 1.0723 - loss: 2.2149 - val_emotional_state_accuracy: 0.3542 - val_emotional_state_loss: 1.4784 - val_intensity_loss: 2.3645 - val_intensity_mae: 1.2827 - val_loss: 2.7221 - learning_rate: 3.0000e-04
# Epoch 20/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.4367 - emotional_state_loss: 1.3249 - intensity_loss: 1.5304 - intensity_mae: 1.0611 - loss: 2.1517 - val_emotional_state_accuracy: 0.3750 - val_emotional_state_loss: 1.4593 - val_intensity_loss: 2.4380 - val_intensity_mae: 1.2989 - val_loss: 2.7400 - learning_rate: 3.0000e-04
# Epoch 21/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.4529 - emotional_state_loss: 1.2973 - intensity_loss: 1.5256 - intensity_mae: 1.0564 - loss: 2.1219 - val_emotional_state_accuracy: 0.4167 - val_emotional_state_loss: 1.4472 - val_intensity_loss: 2.4342 - val_intensity_mae: 1.3142 - val_loss: 2.7262 - learning_rate: 3.0000e-04
# Epoch 22/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.4573 - emotional_state_loss: 1.2754 - intensity_loss: 1.4805 - intensity_mae: 1.0330 - loss: 2.0776 - val_emotional_state_accuracy: 0.4208 - val_emotional_state_loss: 1.4082 - val_intensity_loss: 2.4162 - val_intensity_mae: 1.3139 - val_loss: 2.6783 - learning_rate: 3.0000e-04
# Epoch 23/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - emotional_state_accuracy: 0.4589 - emotional_state_loss: 1.2685 - intensity_loss: 1.4523 - intensity_mae: 1.0290 - loss: 2.0568 - val_emotional_state_accuracy: 0.4208 - val_emotional_state_loss: 1.3896 - val_intensity_loss: 2.4834 - val_intensity_mae: 1.3083 - val_loss: 2.6935 - learning_rate: 3.0000e-04
# Epoch 24/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.4922 - emotional_state_loss: 1.2180 - intensity_loss: 1.4025 - intensity_mae: 1.0104 - loss: 1.9816 - val_emotional_state_accuracy: 0.4292 - val_emotional_state_loss: 1.3866 - val_intensity_loss: 2.5031 - val_intensity_mae: 1.3216 - val_loss: 2.7006 - learning_rate: 3.0000e-04
# Epoch 25/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.4872 - emotional_state_loss: 1.1825 - intensity_loss: 1.4015 - intensity_mae: 1.0055 - loss: 1.9457 - val_emotional_state_accuracy: 0.4542 - val_emotional_state_loss: 1.3558 - val_intensity_loss: 2.4209 - val_intensity_mae: 1.3030 - val_loss: 2.6289 - learning_rate: 3.0000e-04
# Epoch 26/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.5148 - emotional_state_loss: 1.1745 - intensity_loss: 1.3777 - intensity_mae: 1.0000 - loss: 1.9260 - val_emotional_state_accuracy: 0.4333 - val_emotional_state_loss: 1.3394 - val_intensity_loss: 2.4804 - val_intensity_mae: 1.3263 - val_loss: 2.6424 - learning_rate: 3.0000e-04
# Epoch 27/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.5279 - emotional_state_loss: 1.1369 - intensity_loss: 1.3203 - intensity_mae: 0.9815 - loss: 1.8599 - val_emotional_state_accuracy: 0.4708 - val_emotional_state_loss: 1.3109 - val_intensity_loss: 2.4459 - val_intensity_mae: 1.3083 - val_loss: 2.5968 - learning_rate: 3.0000e-04
# Epoch 28/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.5312 - emotional_state_loss: 1.1228 - intensity_loss: 1.3444 - intensity_mae: 0.9843 - loss: 1.8581 - val_emotional_state_accuracy: 0.4667 - val_emotional_state_loss: 1.2752 - val_intensity_loss: 2.5080 - val_intensity_mae: 1.3140 - val_loss: 2.5924 - learning_rate: 3.0000e-04
# Epoch 29/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.5497 - emotional_state_loss: 1.0866 - intensity_loss: 1.2840 - intensity_mae: 0.9674 - loss: 1.7919 - val_emotional_state_accuracy: 0.4667 - val_emotional_state_loss: 1.2845 - val_intensity_loss: 2.3996 - val_intensity_mae: 1.2808 - val_loss: 2.5477 - learning_rate: 3.0000e-04
# Epoch 30/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.5708 - emotional_state_loss: 1.0545 - intensity_loss: 1.2637 - intensity_mae: 0.9465 - loss: 1.7497 - val_emotional_state_accuracy: 0.4750 - val_emotional_state_loss: 1.2899 - val_intensity_loss: 2.5749 - val_intensity_mae: 1.3344 - val_loss: 2.6409 - learning_rate: 3.0000e-04
# Epoch 31/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.5799 - emotional_state_loss: 1.0299 - intensity_loss: 1.2272 - intensity_mae: 0.9335 - loss: 1.7071 - val_emotional_state_accuracy: 0.4750 - val_emotional_state_loss: 1.2853 - val_intensity_loss: 2.5197 - val_intensity_mae: 1.3079 - val_loss: 2.6089 - learning_rate: 3.0000e-04
# Epoch 32/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.6026 - emotional_state_loss: 0.9771 - intensity_loss: 1.1961 - intensity_mae: 0.9309 - loss: 1.6389 - val_emotional_state_accuracy: 0.4792 - val_emotional_state_loss: 1.2734 - val_intensity_loss: 2.5795 - val_intensity_mae: 1.3299 - val_loss: 2.6271 - learning_rate: 3.0000e-04
# Epoch 33/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - emotional_state_accuracy: 0.6099 - emotional_state_loss: 0.9600 - intensity_loss: 1.1899 - intensity_mae: 0.9212 - loss: 1.6190 - val_emotional_state_accuracy: 0.4792 - val_emotional_state_loss: 1.2403 - val_intensity_loss: 2.5155 - val_intensity_mae: 1.3168 - val_loss: 2.5622 - learning_rate: 3.0000e-04
# Epoch 34/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.6284 - emotional_state_loss: 0.9303 - intensity_loss: 1.1915 - intensity_mae: 0.9212 - loss: 1.5902 - val_emotional_state_accuracy: 0.5083 - val_emotional_state_loss: 1.2119 - val_intensity_loss: 2.6138 - val_intensity_mae: 1.3435 - val_loss: 2.5832 - learning_rate: 3.0000e-04
# Epoch 35/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.6344 - emotional_state_loss: 0.9086 - intensity_loss: 1.1301 - intensity_mae: 0.8949 - loss: 1.5380 - val_emotional_state_accuracy: 0.5208 - val_emotional_state_loss: 1.2118 - val_intensity_loss: 2.6637 - val_intensity_mae: 1.3388 - val_loss: 2.6081 - learning_rate: 3.0000e-04
# Epoch 36/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.6307 - emotional_state_loss: 0.9055 - intensity_loss: 1.1171 - intensity_mae: 0.8941 - loss: 1.5286 - val_emotional_state_accuracy: 0.5042 - val_emotional_state_loss: 1.2036 - val_intensity_loss: 2.6477 - val_intensity_mae: 1.3140 - val_loss: 2.5921 - learning_rate: 3.0000e-04
# Epoch 37/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.6479 - emotional_state_loss: 0.8757 - intensity_loss: 1.1102 - intensity_mae: 0.8902 - loss: 1.4955 - val_emotional_state_accuracy: 0.5250 - val_emotional_state_loss: 1.1999 - val_intensity_loss: 2.5127 - val_intensity_mae: 1.2862 - val_loss: 2.5211 - learning_rate: 3.0000e-04
# Epoch 38/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.6599 - emotional_state_loss: 0.8514 - intensity_loss: 1.0587 - intensity_mae: 0.8588 - loss: 1.4456 - val_emotional_state_accuracy: 0.5542 - val_emotional_state_loss: 1.1696 - val_intensity_loss: 2.4963 - val_intensity_mae: 1.2994 - val_loss: 2.4828 - learning_rate: 3.0000e-04
# Epoch 39/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.6570 - emotional_state_loss: 0.8418 - intensity_loss: 1.0705 - intensity_mae: 0.8687 - loss: 1.4421 - val_emotional_state_accuracy: 0.5542 - val_emotional_state_loss: 1.1965 - val_intensity_loss: 2.6365 - val_intensity_mae: 1.3400 - val_loss: 2.5800 - learning_rate: 3.0000e-04
# Epoch 40/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - emotional_state_accuracy: 0.6654 - emotional_state_loss: 0.8196 - intensity_loss: 1.0456 - intensity_mae: 0.8607 - loss: 1.4077 - val_emotional_state_accuracy: 0.5375 - val_emotional_state_loss: 1.1733 - val_intensity_loss: 2.5652 - val_intensity_mae: 1.3110 - val_loss: 2.5212 - learning_rate: 3.0000e-04
# Epoch 41/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - emotional_state_accuracy: 0.6734 - emotional_state_loss: 0.8046 - intensity_loss: 1.0622 - intensity_mae: 0.8679 - loss: 1.4011 - val_emotional_state_accuracy: 0.5333 - val_emotional_state_loss: 1.1784 - val_intensity_loss: 2.5338 - val_intensity_mae: 1.3036 - val_loss: 2.5109 - learning_rate: 3.0000e-04
# Epoch 42/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.6815 - emotional_state_loss: 0.7811 - intensity_loss: 1.0485 - intensity_mae: 0.8584 - loss: 1.3709 - val_emotional_state_accuracy: 0.5458 - val_emotional_state_loss: 1.1739 - val_intensity_loss: 2.5403 - val_intensity_mae: 1.2947 - val_loss: 2.5098 - learning_rate: 3.0000e-04
# Epoch 43/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.6943 - emotional_state_loss: 0.7392 - intensity_loss: 1.0234 - intensity_mae: 0.8453 - loss: 1.3167 - val_emotional_state_accuracy: 0.5458 - val_emotional_state_loss: 1.1852 - val_intensity_loss: 2.5968 - val_intensity_mae: 1.3120 - val_loss: 2.5495 - learning_rate: 3.0000e-04
# Epoch 44/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.7042 - emotional_state_loss: 0.7124 - intensity_loss: 0.9538 - intensity_mae: 0.8157 - loss: 1.2552 - val_emotional_state_accuracy: 0.5500 - val_emotional_state_loss: 1.2035 - val_intensity_loss: 2.5473 - val_intensity_mae: 1.3101 - val_loss: 2.5432 - learning_rate: 3.0000e-04
# Epoch 45/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.7031 - emotional_state_loss: 0.7227 - intensity_loss: 1.0204 - intensity_mae: 0.8442 - loss: 1.2990 - val_emotional_state_accuracy: 0.5375 - val_emotional_state_loss: 1.2071 - val_intensity_loss: 2.6264 - val_intensity_mae: 1.3409 - val_loss: 2.5865 - learning_rate: 3.0000e-04
# Epoch 46/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - emotional_state_accuracy: 0.7099 - emotional_state_loss: 0.7235 - intensity_loss: 0.9540 - intensity_mae: 0.8148 - loss: 1.2668 - val_emotional_state_accuracy: 0.5750 - val_emotional_state_loss: 1.1669 - val_intensity_loss: 2.6078 - val_intensity_mae: 1.3299 - val_loss: 2.5371 - learning_rate: 3.0000e-04
# Epoch 47/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.7190 - emotional_state_loss: 0.6947 - intensity_loss: 0.9800 - intensity_mae: 0.8226 - loss: 1.2511 - val_emotional_state_accuracy: 0.5458 - val_emotional_state_loss: 1.1882 - val_intensity_loss: 2.5818 - val_intensity_mae: 1.3177 - val_loss: 2.5456 - learning_rate: 3.0000e-04
# Epoch 48/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.7258 - emotional_state_loss: 0.6897 - intensity_loss: 0.9574 - intensity_mae: 0.8140 - loss: 1.2349 - val_emotional_state_accuracy: 0.5708 - val_emotional_state_loss: 1.1727 - val_intensity_loss: 2.5139 - val_intensity_mae: 1.2995 - val_loss: 2.4963 - learning_rate: 3.0000e-04
# Epoch 49/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.7323 - emotional_state_loss: 0.6660 - intensity_loss: 0.9724 - intensity_mae: 0.8216 - loss: 1.2189 - val_emotional_state_accuracy: 0.5417 - val_emotional_state_loss: 1.1942 - val_intensity_loss: 2.6344 - val_intensity_mae: 1.3328 - val_loss: 2.5783 - learning_rate: 3.0000e-04
# Epoch 50/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.7406 - emotional_state_loss: 0.6745 - intensity_loss: 0.9495 - intensity_mae: 0.8069 - loss: 1.2161 - val_emotional_state_accuracy: 0.5417 - val_emotional_state_loss: 1.2086 - val_intensity_loss: 2.6312 - val_intensity_mae: 1.3313 - val_loss: 2.5912 - learning_rate: 3.0000e-04
# Epoch 51/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - emotional_state_accuracy: 0.7490 - emotional_state_loss: 0.6150 - intensity_loss: 0.9335 - intensity_mae: 0.8072 - loss: 1.1488 - val_emotional_state_accuracy: 0.5625 - val_emotional_state_loss: 1.1832 - val_intensity_loss: 2.5899 - val_intensity_mae: 1.3167 - val_loss: 2.5452 - learning_rate: 1.5000e-04
# Epoch 52/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.7477 - emotional_state_loss: 0.6223 - intensity_loss: 0.8842 - intensity_mae: 0.7777 - loss: 1.1314 - val_emotional_state_accuracy: 0.5625 - val_emotional_state_loss: 1.1880 - val_intensity_loss: 2.6599 - val_intensity_mae: 1.3347 - val_loss: 2.5850 - learning_rate: 1.5000e-04
# Epoch 53/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.7648 - emotional_state_loss: 0.5900 - intensity_loss: 0.8428 - intensity_mae: 0.7637 - loss: 1.0785 - val_emotional_state_accuracy: 0.5500 - val_emotional_state_loss: 1.1941 - val_intensity_loss: 2.7540 - val_intensity_mae: 1.3627 - val_loss: 2.6382 - learning_rate: 1.5000e-04
# Epoch 54/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.7594 - emotional_state_loss: 0.5876 - intensity_loss: 0.8920 - intensity_mae: 0.7767 - loss: 1.1007 - val_emotional_state_accuracy: 0.5667 - val_emotional_state_loss: 1.1941 - val_intensity_loss: 2.7085 - val_intensity_mae: 1.3407 - val_loss: 2.6154 - learning_rate: 1.5000e-04
# Epoch 55/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.7706 - emotional_state_loss: 0.5745 - intensity_loss: 0.8207 - intensity_mae: 0.7502 - loss: 1.0519 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.1575 - val_intensity_loss: 2.7230 - val_intensity_mae: 1.3495 - val_loss: 2.5861 - learning_rate: 1.5000e-04
# Epoch 56/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - emotional_state_accuracy: 0.7594 - emotional_state_loss: 0.5898 - intensity_loss: 0.8421 - intensity_mae: 0.7672 - loss: 1.0780 - val_emotional_state_accuracy: 0.5875 - val_emotional_state_loss: 1.1937 - val_intensity_loss: 2.7826 - val_intensity_mae: 1.3784 - val_loss: 2.6521 - learning_rate: 1.5000e-04
# Epoch 57/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.7768 - emotional_state_loss: 0.5672 - intensity_loss: 0.8378 - intensity_mae: 0.7596 - loss: 1.0532 - val_emotional_state_accuracy: 0.5708 - val_emotional_state_loss: 1.1910 - val_intensity_loss: 2.7089 - val_intensity_mae: 1.3494 - val_loss: 2.6126 - learning_rate: 1.5000e-04
# Epoch 58/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.7708 - emotional_state_loss: 0.5719 - intensity_loss: 0.8286 - intensity_mae: 0.7533 - loss: 1.0533 - val_emotional_state_accuracy: 0.5708 - val_emotional_state_loss: 1.1868 - val_intensity_loss: 2.7417 - val_intensity_mae: 1.3474 - val_loss: 2.6248 - learning_rate: 1.5000e-04
# Epoch 59/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.7823 - emotional_state_loss: 0.5488 - intensity_loss: 0.8133 - intensity_mae: 0.7455 - loss: 1.0225 - val_emotional_state_accuracy: 0.5750 - val_emotional_state_loss: 1.1926 - val_intensity_loss: 2.6929 - val_intensity_mae: 1.3360 - val_loss: 2.6061 - learning_rate: 1.5000e-04
# Epoch 60/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.7768 - emotional_state_loss: 0.5387 - intensity_loss: 0.7836 - intensity_mae: 0.7328 - loss: 0.9977 - val_emotional_state_accuracy: 0.5833 - val_emotional_state_loss: 1.2117 - val_intensity_loss: 2.7360 - val_intensity_mae: 1.3515 - val_loss: 2.6469 - learning_rate: 1.5000e-04
# Epoch 61/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.7810 - emotional_state_loss: 0.5411 - intensity_loss: 0.8081 - intensity_mae: 0.7461 - loss: 1.0123 - val_emotional_state_accuracy: 0.5833 - val_emotional_state_loss: 1.2187 - val_intensity_loss: 2.7393 - val_intensity_mae: 1.3493 - val_loss: 2.6555 - learning_rate: 1.5000e-04
# Epoch 62/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.7924 - emotional_state_loss: 0.5301 - intensity_loss: 0.7949 - intensity_mae: 0.7331 - loss: 0.9947 - val_emotional_state_accuracy: 0.5750 - val_emotional_state_loss: 1.2432 - val_intensity_loss: 2.7169 - val_intensity_mae: 1.3353 - val_loss: 2.6688 - learning_rate: 1.5000e-04
# Epoch 63/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.8003 - emotional_state_loss: 0.5158 - intensity_loss: 0.7732 - intensity_mae: 0.7247 - loss: 0.9695 - val_emotional_state_accuracy: 0.5833 - val_emotional_state_loss: 1.2294 - val_intensity_loss: 2.6703 - val_intensity_mae: 1.3272 - val_loss: 2.6318 - learning_rate: 7.5000e-05
# Epoch 64/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.7924 - emotional_state_loss: 0.5203 - intensity_loss: 0.7871 - intensity_mae: 0.7344 - loss: 0.9810 - val_emotional_state_accuracy: 0.5583 - val_emotional_state_loss: 1.2209 - val_intensity_loss: 2.7030 - val_intensity_mae: 1.3353 - val_loss: 2.6396 - learning_rate: 7.5000e-05
# Epoch 65/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - emotional_state_accuracy: 0.7958 - emotional_state_loss: 0.5035 - intensity_loss: 0.7911 - intensity_mae: 0.7419 - loss: 0.9662 - val_emotional_state_accuracy: 0.5750 - val_emotional_state_loss: 1.2230 - val_intensity_loss: 2.6770 - val_intensity_mae: 1.3313 - val_loss: 2.6287 - learning_rate: 7.5000e-05
# Epoch 66/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.8117 - emotional_state_loss: 0.4737 - intensity_loss: 0.7650 - intensity_mae: 0.7198 - loss: 0.9234 - val_emotional_state_accuracy: 0.5750 - val_emotional_state_loss: 1.2314 - val_intensity_loss: 2.6900 - val_intensity_mae: 1.3394 - val_loss: 2.6435 - learning_rate: 7.5000e-05
# Epoch 67/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.7984 - emotional_state_loss: 0.5008 - intensity_loss: 0.7753 - intensity_mae: 0.7253 - loss: 0.9556 - val_emotional_state_accuracy: 0.5792 - val_emotional_state_loss: 1.2327 - val_intensity_loss: 2.7597 - val_intensity_mae: 1.3506 - val_loss: 2.6797 - learning_rate: 7.5000e-05
# Epoch 68/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.7992 - emotional_state_loss: 0.4973 - intensity_loss: 0.8016 - intensity_mae: 0.7358 - loss: 0.9653 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2201 - val_intensity_loss: 2.7059 - val_intensity_mae: 1.3363 - val_loss: 2.6401 - learning_rate: 7.5000e-05
# Epoch 69/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.8023 - emotional_state_loss: 0.5174 - intensity_loss: 0.7951 - intensity_mae: 0.7359 - loss: 0.9821 - val_emotional_state_accuracy: 0.5750 - val_emotional_state_loss: 1.2504 - val_intensity_loss: 2.7120 - val_intensity_mae: 1.3349 - val_loss: 2.6735 - learning_rate: 7.5000e-05
# Epoch 70/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - emotional_state_accuracy: 0.7987 - emotional_state_loss: 0.5029 - intensity_loss: 0.7524 - intensity_mae: 0.7119 - loss: 0.9462 - val_emotional_state_accuracy: 0.5583 - val_emotional_state_loss: 1.2748 - val_intensity_loss: 2.7445 - val_intensity_mae: 1.3456 - val_loss: 2.7141 - learning_rate: 7.5000e-05
# Epoch 71/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.8000 - emotional_state_loss: 0.5081 - intensity_loss: 0.7858 - intensity_mae: 0.7311 - loss: 0.9681 - val_emotional_state_accuracy: 0.5750 - val_emotional_state_loss: 1.2594 - val_intensity_loss: 2.7067 - val_intensity_mae: 1.3359 - val_loss: 2.6799 - learning_rate: 7.5000e-05
# Epoch 72/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.8008 - emotional_state_loss: 0.4817 - intensity_loss: 0.7563 - intensity_mae: 0.7224 - loss: 0.9270 - val_emotional_state_accuracy: 0.5833 - val_emotional_state_loss: 1.2432 - val_intensity_loss: 2.7932 - val_intensity_mae: 1.3561 - val_loss: 2.7069 - learning_rate: 7.5000e-05
# Epoch 73/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.8091 - emotional_state_loss: 0.4857 - intensity_loss: 0.7552 - intensity_mae: 0.7157 - loss: 0.9304 - val_emotional_state_accuracy: 0.5958 - val_emotional_state_loss: 1.2474 - val_intensity_loss: 2.7503 - val_intensity_mae: 1.3443 - val_loss: 2.6896 - learning_rate: 7.5000e-05
# Epoch 74/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.8102 - emotional_state_loss: 0.4709 - intensity_loss: 0.7545 - intensity_mae: 0.7098 - loss: 0.9152 - val_emotional_state_accuracy: 0.5708 - val_emotional_state_loss: 1.2559 - val_intensity_loss: 2.7077 - val_intensity_mae: 1.3348 - val_loss: 2.6768 - learning_rate: 7.5000e-05
# Epoch 75/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - emotional_state_accuracy: 0.8060 - emotional_state_loss: 0.4818 - intensity_loss: 0.7822 - intensity_mae: 0.7256 - loss: 0.9400 - val_emotional_state_accuracy: 0.5750 - val_emotional_state_loss: 1.2620 - val_intensity_loss: 2.7339 - val_intensity_mae: 1.3424 - val_loss: 2.6961 - learning_rate: 3.7500e-05
# Epoch 76/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.8154 - emotional_state_loss: 0.4536 - intensity_loss: 0.7244 - intensity_mae: 0.7027 - loss: 0.8829 - val_emotional_state_accuracy: 0.5708 - val_emotional_state_loss: 1.2731 - val_intensity_loss: 2.7484 - val_intensity_mae: 1.3446 - val_loss: 2.7144 - learning_rate: 3.7500e-05
# Epoch 77/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.8190 - emotional_state_loss: 0.4634 - intensity_loss: 0.7623 - intensity_mae: 0.7144 - loss: 0.9116 - val_emotional_state_accuracy: 0.5792 - val_emotional_state_loss: 1.2652 - val_intensity_loss: 2.7533 - val_intensity_mae: 1.3445 - val_loss: 2.7089 - learning_rate: 3.7500e-05
# Epoch 78/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.8221 - emotional_state_loss: 0.4364 - intensity_loss: 0.7654 - intensity_mae: 0.7148 - loss: 0.8861 - val_emotional_state_accuracy: 0.5792 - val_emotional_state_loss: 1.2615 - val_intensity_loss: 2.7345 - val_intensity_mae: 1.3430 - val_loss: 2.6958 - learning_rate: 3.7500e-05
# Epoch 79/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.8094 - emotional_state_loss: 0.4591 - intensity_loss: 0.7193 - intensity_mae: 0.7033 - loss: 0.8858 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2670 - val_intensity_loss: 2.7428 - val_intensity_mae: 1.3426 - val_loss: 2.7054 - learning_rate: 3.7500e-05
# Epoch 80/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.8115 - emotional_state_loss: 0.4693 - intensity_loss: 0.7303 - intensity_mae: 0.7084 - loss: 0.9015 - val_emotional_state_accuracy: 0.5833 - val_emotional_state_loss: 1.2644 - val_intensity_loss: 2.7485 - val_intensity_mae: 1.3427 - val_loss: 2.7056 - learning_rate: 3.7500e-05
# Epoch 81/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - emotional_state_accuracy: 0.8195 - emotional_state_loss: 0.4495 - intensity_loss: 0.7509 - intensity_mae: 0.7094 - loss: 0.8920 - val_emotional_state_accuracy: 0.5958 - val_emotional_state_loss: 1.2597 - val_intensity_loss: 2.7294 - val_intensity_mae: 1.3406 - val_loss: 2.6914 - learning_rate: 3.7500e-05
# Epoch 82/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.8143 - emotional_state_loss: 0.4655 - intensity_loss: 0.7383 - intensity_mae: 0.7118 - loss: 0.9016 - val_emotional_state_accuracy: 0.5875 - val_emotional_state_loss: 1.2529 - val_intensity_loss: 2.7597 - val_intensity_mae: 1.3484 - val_loss: 2.6998 - learning_rate: 3.7500e-05
# Epoch 83/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.8117 - emotional_state_loss: 0.4750 - intensity_loss: 0.7375 - intensity_mae: 0.7002 - loss: 0.9108 - val_emotional_state_accuracy: 0.5875 - val_emotional_state_loss: 1.2700 - val_intensity_loss: 2.7725 - val_intensity_mae: 1.3534 - val_loss: 2.7232 - learning_rate: 3.7500e-05
# Epoch 84/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.8094 - emotional_state_loss: 0.4856 - intensity_loss: 0.7228 - intensity_mae: 0.7013 - loss: 0.9140 - val_emotional_state_accuracy: 0.5792 - val_emotional_state_loss: 1.2841 - val_intensity_loss: 2.8006 - val_intensity_mae: 1.3609 - val_loss: 2.7514 - learning_rate: 3.7500e-05
# Epoch 85/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.8320 - emotional_state_loss: 0.4155 - intensity_loss: 0.7254 - intensity_mae: 0.7024 - loss: 0.8452 - val_emotional_state_accuracy: 0.5833 - val_emotional_state_loss: 1.2639 - val_intensity_loss: 2.8134 - val_intensity_mae: 1.3657 - val_loss: 2.7375 - learning_rate: 3.7500e-05
# Epoch 86/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.8258 - emotional_state_loss: 0.4287 - intensity_loss: 0.6950 - intensity_mae: 0.6829 - loss: 0.8432 - val_emotional_state_accuracy: 0.5708 - val_emotional_state_loss: 1.2901 - val_intensity_loss: 2.7727 - val_intensity_mae: 1.3516 - val_loss: 2.7434 - learning_rate: 3.7500e-05
# Epoch 87/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.8133 - emotional_state_loss: 0.4602 - intensity_loss: 0.7481 - intensity_mae: 0.7072 - loss: 0.9012 - val_emotional_state_accuracy: 0.5833 - val_emotional_state_loss: 1.3015 - val_intensity_loss: 2.8014 - val_intensity_mae: 1.3639 - val_loss: 2.7691 - learning_rate: 1.8750e-05
# Epoch 88/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - emotional_state_accuracy: 0.8159 - emotional_state_loss: 0.4669 - intensity_loss: 0.7227 - intensity_mae: 0.6972 - loss: 0.8952 - val_emotional_state_accuracy: 0.5833 - val_emotional_state_loss: 1.2783 - val_intensity_loss: 2.7789 - val_intensity_mae: 1.3556 - val_loss: 2.7347 - learning_rate: 1.8750e-05
# Epoch 89/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.8271 - emotional_state_loss: 0.4359 - intensity_loss: 0.7469 - intensity_mae: 0.7108 - loss: 0.8763 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2970 - val_intensity_loss: 2.8053 - val_intensity_mae: 1.3628 - val_loss: 2.7666 - learning_rate: 1.8750e-05
# Epoch 90/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.8190 - emotional_state_loss: 0.4486 - intensity_loss: 0.7113 - intensity_mae: 0.6922 - loss: 0.8712 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2795 - val_intensity_loss: 2.7806 - val_intensity_mae: 1.3478 - val_loss: 2.7367 - learning_rate: 1.8750e-05
# Epoch 91/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.8315 - emotional_state_loss: 0.4258 - intensity_loss: 0.7264 - intensity_mae: 0.7034 - loss: 0.8560 - val_emotional_state_accuracy: 0.5750 - val_emotional_state_loss: 1.2739 - val_intensity_loss: 2.7960 - val_intensity_mae: 1.3550 - val_loss: 2.7389 - learning_rate: 1.8750e-05
# Epoch 92/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.8271 - emotional_state_loss: 0.4329 - intensity_loss: 0.7226 - intensity_mae: 0.7062 - loss: 0.8611 - val_emotional_state_accuracy: 0.5875 - val_emotional_state_loss: 1.2772 - val_intensity_loss: 2.7546 - val_intensity_mae: 1.3474 - val_loss: 2.7215 - learning_rate: 1.8750e-05
# Epoch 93/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - emotional_state_accuracy: 0.8143 - emotional_state_loss: 0.4600 - intensity_loss: 0.7340 - intensity_mae: 0.7028 - loss: 0.8939 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2695 - val_intensity_loss: 2.7974 - val_intensity_mae: 1.3612 - val_loss: 2.7351 - learning_rate: 1.8750e-05
# Epoch 94/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.8247 - emotional_state_loss: 0.4512 - intensity_loss: 0.7394 - intensity_mae: 0.7043 - loss: 0.8878 - val_emotional_state_accuracy: 0.5833 - val_emotional_state_loss: 1.2844 - val_intensity_loss: 2.7875 - val_intensity_mae: 1.3556 - val_loss: 2.7451 - learning_rate: 1.8750e-05
# Epoch 95/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.8323 - emotional_state_loss: 0.4410 - intensity_loss: 0.7322 - intensity_mae: 0.7011 - loss: 0.8740 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2720 - val_intensity_loss: 2.7774 - val_intensity_mae: 1.3530 - val_loss: 2.7276 - learning_rate: 1.8750e-05
# Epoch 96/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.8117 - emotional_state_loss: 0.4601 - intensity_loss: 0.7214 - intensity_mae: 0.6983 - loss: 0.8878 - val_emotional_state_accuracy: 0.5833 - val_emotional_state_loss: 1.2862 - val_intensity_loss: 2.7698 - val_intensity_mae: 1.3485 - val_loss: 2.7381 - learning_rate: 1.8750e-05
# Epoch 97/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.8253 - emotional_state_loss: 0.4304 - intensity_loss: 0.7237 - intensity_mae: 0.6968 - loss: 0.8592 - val_emotional_state_accuracy: 0.5833 - val_emotional_state_loss: 1.2866 - val_intensity_loss: 2.7914 - val_intensity_mae: 1.3541 - val_loss: 2.7492 - learning_rate: 1.8750e-05
# Epoch 98/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.8271 - emotional_state_loss: 0.4157 - intensity_loss: 0.7172 - intensity_mae: 0.6975 - loss: 0.8412 - val_emotional_state_accuracy: 0.5958 - val_emotional_state_loss: 1.2785 - val_intensity_loss: 2.7666 - val_intensity_mae: 1.3499 - val_loss: 2.7287 - learning_rate: 1.8750e-05
# Epoch 99/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.8273 - emotional_state_loss: 0.4217 - intensity_loss: 0.6743 - intensity_mae: 0.6826 - loss: 0.8258 - val_emotional_state_accuracy: 0.5833 - val_emotional_state_loss: 1.2675 - val_intensity_loss: 2.7899 - val_intensity_mae: 1.3581 - val_loss: 2.7293 - learning_rate: 9.3750e-06
# Epoch 100/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.8224 - emotional_state_loss: 0.4461 - intensity_loss: 0.7132 - intensity_mae: 0.6966 - loss: 0.8696 - val_emotional_state_accuracy: 0.6000 - val_emotional_state_loss: 1.2687 - val_intensity_loss: 2.7819 - val_intensity_mae: 1.3535 - val_loss: 2.7265 - learning_rate: 9.3750e-06
# Epoch 101/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.8305 - emotional_state_loss: 0.4296 - intensity_loss: 0.7250 - intensity_mae: 0.6962 - loss: 0.8590 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2777 - val_intensity_loss: 2.7826 - val_intensity_mae: 1.3587 - val_loss: 2.7359 - learning_rate: 9.3750e-06
# Epoch 102/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.8266 - emotional_state_loss: 0.4344 - intensity_loss: 0.7149 - intensity_mae: 0.6986 - loss: 0.8587 - val_emotional_state_accuracy: 0.5875 - val_emotional_state_loss: 1.2901 - val_intensity_loss: 2.7602 - val_intensity_mae: 1.3500 - val_loss: 2.7371 - learning_rate: 9.3750e-06
# Epoch 103/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.8341 - emotional_state_loss: 0.4166 - intensity_loss: 0.7060 - intensity_mae: 0.6949 - loss: 0.8364 - val_emotional_state_accuracy: 0.5792 - val_emotional_state_loss: 1.2780 - val_intensity_loss: 2.8043 - val_intensity_mae: 1.3604 - val_loss: 2.7470 - learning_rate: 9.3750e-06
# Epoch 104/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.8247 - emotional_state_loss: 0.4245 - intensity_loss: 0.6907 - intensity_mae: 0.6801 - loss: 0.8367 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2781 - val_intensity_loss: 2.7863 - val_intensity_mae: 1.3593 - val_loss: 2.7382 - learning_rate: 9.3750e-06
# Epoch 105/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - emotional_state_accuracy: 0.8328 - emotional_state_loss: 0.4209 - intensity_loss: 0.6953 - intensity_mae: 0.6826 - loss: 0.8355 - val_emotional_state_accuracy: 0.5875 - val_emotional_state_loss: 1.2737 - val_intensity_loss: 2.7773 - val_intensity_mae: 1.3521 - val_loss: 2.7293 - learning_rate: 9.3750e-06
# Epoch 106/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.8279 - emotional_state_loss: 0.4311 - intensity_loss: 0.7380 - intensity_mae: 0.7039 - loss: 0.8671 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2733 - val_intensity_loss: 2.7950 - val_intensity_mae: 1.3582 - val_loss: 2.7377 - learning_rate: 9.3750e-06
# Epoch 107/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.8229 - emotional_state_loss: 0.4466 - intensity_loss: 0.7130 - intensity_mae: 0.6940 - loss: 0.8699 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2663 - val_intensity_loss: 2.7949 - val_intensity_mae: 1.3572 - val_loss: 2.7307 - learning_rate: 9.3750e-06
# Epoch 108/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.8297 - emotional_state_loss: 0.4194 - intensity_loss: 0.7342 - intensity_mae: 0.7067 - loss: 0.8534 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2950 - val_intensity_loss: 2.7878 - val_intensity_mae: 1.3583 - val_loss: 2.7557 - learning_rate: 9.3750e-06
# Epoch 109/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - emotional_state_accuracy: 0.8229 - emotional_state_loss: 0.4408 - intensity_loss: 0.7745 - intensity_mae: 0.7270 - loss: 0.8949 - val_emotional_state_accuracy: 0.5958 - val_emotional_state_loss: 1.2892 - val_intensity_loss: 2.7918 - val_intensity_mae: 1.3570 - val_loss: 2.7519 - learning_rate: 9.3750e-06
# Epoch 110/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.8242 - emotional_state_loss: 0.4340 - intensity_loss: 0.6916 - intensity_mae: 0.6845 - loss: 0.8467 - val_emotional_state_accuracy: 0.5958 - val_emotional_state_loss: 1.2624 - val_intensity_loss: 2.7539 - val_intensity_mae: 1.3479 - val_loss: 2.7062 - learning_rate: 9.3750e-06
# Epoch 111/300
# ...
# Epoch 123/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.8315 - emotional_state_loss: 0.4214 - intensity_loss: 0.7282 - intensity_mae: 0.6978 - loss: 0.8523 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2870 - val_intensity_loss: 2.7950 - val_intensity_mae: 1.3567 - val_loss: 2.7514 - learning_rate: 2.3438e-06
# Epoch 124/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.8289 - emotional_state_loss: 0.4242 - intensity_loss: 0.6887 - intensity_mae: 0.6871 - loss: 0.8354 - val_emotional_state_accuracy: 0.5958 - val_emotional_state_loss: 1.2983 - val_intensity_loss: 2.7762 - val_intensity_mae: 1.3538 - val_loss: 2.7533 - learning_rate: 2.3438e-06
# Epoch 125/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.8294 - emotional_state_loss: 0.4168 - intensity_loss: 0.7063 - intensity_mae: 0.6945 - loss: 0.8368 - val_emotional_state_accuracy: 0.5750 - val_emotional_state_loss: 1.2922 - val_intensity_loss: 2.7800 - val_intensity_mae: 1.3528 - val_loss: 2.7491 - learning_rate: 2.3438e-06
# Epoch 126/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - emotional_state_accuracy: 0.8396 - emotional_state_loss: 0.4104 - intensity_loss: 0.6994 - intensity_mae: 0.6881 - loss: 0.8269 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2804 - val_intensity_loss: 2.8110 - val_intensity_mae: 1.3637 - val_loss: 2.7527 - learning_rate: 2.3438e-06
# Epoch 127/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.8323 - emotional_state_loss: 0.4324 - intensity_loss: 0.6832 - intensity_mae: 0.6845 - loss: 0.8408 - val_emotional_state_accuracy: 0.5958 - val_emotional_state_loss: 1.2865 - val_intensity_loss: 2.7720 - val_intensity_mae: 1.3502 - val_loss: 2.7393 - learning_rate: 2.3438e-06
# Epoch 128/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - emotional_state_accuracy: 0.8193 - emotional_state_loss: 0.4468 - intensity_loss: 0.7169 - intensity_mae: 0.6970 - loss: 0.8721 - val_emotional_state_accuracy: 0.6042 - val_emotional_state_loss: 1.2776 - val_intensity_loss: 2.7758 - val_intensity_mae: 1.3548 - val_loss: 2.7323 - learning_rate: 2.3438e-06
# Epoch 129/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - emotional_state_accuracy: 0.8310 - emotional_state_loss: 0.4185 - intensity_loss: 0.7275 - intensity_mae: 0.7006 - loss: 0.8491 - val_emotional_state_accuracy: 0.5958 - val_emotional_state_loss: 1.2720 - val_intensity_loss: 2.7778 - val_intensity_mae: 1.3541 - val_loss: 2.7277 - learning_rate: 2.3438e-06
# Epoch 130/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.8344 - emotional_state_loss: 0.4213 - intensity_loss: 0.7136 - intensity_mae: 0.6900 - loss: 0.8450 - val_emotional_state_accuracy: 0.5833 - val_emotional_state_loss: 1.2862 - val_intensity_loss: 2.7644 - val_intensity_mae: 1.3473 - val_loss: 2.7352 - learning_rate: 2.3438e-06
# Epoch 131/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.8344 - emotional_state_loss: 0.4184 - intensity_loss: 0.6949 - intensity_mae: 0.6838 - loss: 0.8327 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2780 - val_intensity_loss: 2.8036 - val_intensity_mae: 1.3543 - val_loss: 2.7467 - learning_rate: 2.3438e-06
# Epoch 132/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.8284 - emotional_state_loss: 0.4250 - intensity_loss: 0.7048 - intensity_mae: 0.6910 - loss: 0.8443 - val_emotional_state_accuracy: 0.5958 - val_emotional_state_loss: 1.2733 - val_intensity_loss: 2.7775 - val_intensity_mae: 1.3534 - val_loss: 2.7288 - learning_rate: 2.3438e-06
# Epoch 133/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.8339 - emotional_state_loss: 0.4109 - intensity_loss: 0.7554 - intensity_mae: 0.7197 - loss: 0.8554 - val_emotional_state_accuracy: 0.5958 - val_emotional_state_loss: 1.2918 - val_intensity_loss: 2.7754 - val_intensity_mae: 1.3513 - val_loss: 2.7463 - learning_rate: 2.3438e-06
# Epoch 134/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - emotional_state_accuracy: 0.8273 - emotional_state_loss: 0.4196 - intensity_loss: 0.7084 - intensity_mae: 0.6877 - loss: 0.8407 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2742 - val_intensity_loss: 2.7850 - val_intensity_mae: 1.3545 - val_loss: 2.7335 - learning_rate: 2.3438e-06
# Epoch 135/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.8242 - emotional_state_loss: 0.4432 - intensity_loss: 0.6890 - intensity_mae: 0.6825 - loss: 0.8546 - val_emotional_state_accuracy: 0.5875 - val_emotional_state_loss: 1.2942 - val_intensity_loss: 2.8069 - val_intensity_mae: 1.3620 - val_loss: 2.7646 - learning_rate: 1.1719e-06
# Epoch 136/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.8357 - emotional_state_loss: 0.4192 - intensity_loss: 0.7145 - intensity_mae: 0.6876 - loss: 0.8433 - val_emotional_state_accuracy: 0.5958 - val_emotional_state_loss: 1.2838 - val_intensity_loss: 2.7874 - val_intensity_mae: 1.3567 - val_loss: 2.7443 - learning_rate: 1.1719e-06
# Epoch 137/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.8328 - emotional_state_loss: 0.4135 - intensity_loss: 0.7093 - intensity_mae: 0.6935 - loss: 0.8350 - val_emotional_state_accuracy: 0.5875 - val_emotional_state_loss: 1.2894 - val_intensity_loss: 2.7778 - val_intensity_mae: 1.3480 - val_loss: 2.7452 - learning_rate: 1.1719e-06
# Epoch 138/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - emotional_state_accuracy: 0.8354 - emotional_state_loss: 0.4127 - intensity_loss: 0.7019 - intensity_mae: 0.6913 - loss: 0.8305 - val_emotional_state_accuracy: 0.5833 - val_emotional_state_loss: 1.2847 - val_intensity_loss: 2.7900 - val_intensity_mae: 1.3548 - val_loss: 2.7465 - learning_rate: 1.1719e-06
# Epoch 139/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.8240 - emotional_state_loss: 0.4405 - intensity_loss: 0.7263 - intensity_mae: 0.6984 - loss: 0.8705 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2822 - val_intensity_loss: 2.7614 - val_intensity_mae: 1.3465 - val_loss: 2.7297 - learning_rate: 1.1719e-06
# Epoch 140/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.8268 - emotional_state_loss: 0.4251 - intensity_loss: 0.7061 - intensity_mae: 0.6969 - loss: 0.8450 - val_emotional_state_accuracy: 0.5792 - val_emotional_state_loss: 1.2928 - val_intensity_loss: 2.7868 - val_intensity_mae: 1.3573 - val_loss: 2.7531 - learning_rate: 1.1719e-06
# Epoch 141/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.8365 - emotional_state_loss: 0.4094 - intensity_loss: 0.7074 - intensity_mae: 0.6914 - loss: 0.8299 - val_emotional_state_accuracy: 0.5833 - val_emotional_state_loss: 1.2855 - val_intensity_loss: 2.8014 - val_intensity_mae: 1.3587 - val_loss: 2.7530 - learning_rate: 1.1719e-06
# Epoch 142/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - emotional_state_accuracy: 0.8273 - emotional_state_loss: 0.4163 - intensity_loss: 0.7127 - intensity_mae: 0.6964 - loss: 0.8394 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2907 - val_intensity_loss: 2.7727 - val_intensity_mae: 1.3492 - val_loss: 2.7439 - learning_rate: 1.1719e-06
# Epoch 143/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - emotional_state_accuracy: 0.8383 - emotional_state_loss: 0.4023 - intensity_loss: 0.6891 - intensity_mae: 0.6824 - loss: 0.8137 - val_emotional_state_accuracy: 0.5875 - val_emotional_state_loss: 1.2827 - val_intensity_loss: 2.7739 - val_intensity_mae: 1.3514 - val_loss: 2.7365 - learning_rate: 1.1719e-06
# Epoch 144/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.8380 - emotional_state_loss: 0.4142 - intensity_loss: 0.6908 - intensity_mae: 0.6827 - loss: 0.8265 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2891 - val_intensity_loss: 2.7812 - val_intensity_mae: 1.3510 - val_loss: 2.7465 - learning_rate: 1.1719e-06
# Epoch 145/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - emotional_state_accuracy: 0.8227 - emotional_state_loss: 0.4346 - intensity_loss: 0.7034 - intensity_mae: 0.6881 - loss: 0.8531 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2874 - val_intensity_loss: 2.7715 - val_intensity_mae: 1.3487 - val_loss: 2.7400 - learning_rate: 1.1719e-06
# Epoch 146/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - emotional_state_accuracy: 0.8302 - emotional_state_loss: 0.4216 - intensity_loss: 0.6864 - intensity_mae: 0.6812 - loss: 0.8316 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2905 - val_intensity_loss: 2.8103 - val_intensity_mae: 1.3626 - val_loss: 2.7625 - learning_rate: 1.1719e-06
# Epoch 147/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - emotional_state_accuracy: 0.8391 - emotional_state_loss: 0.4030 - intensity_loss: 0.7397 - intensity_mae: 0.7097 - loss: 0.8397 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2851 - val_intensity_loss: 2.7594 - val_intensity_mae: 1.3472 - val_loss: 2.7317 - learning_rate: 1.0000e-06
# Epoch 148/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - emotional_state_accuracy: 0.8372 - emotional_state_loss: 0.4089 - intensity_loss: 0.7077 - intensity_mae: 0.6859 - loss: 0.8296 - val_emotional_state_accuracy: 0.5875 - val_emotional_state_loss: 1.2926 - val_intensity_loss: 2.8039 - val_intensity_mae: 1.3605 - val_loss: 2.7614 - learning_rate: 1.0000e-06
# Epoch 149/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - emotional_state_accuracy: 0.8294 - emotional_state_loss: 0.4104 - intensity_loss: 0.6731 - intensity_mae: 0.6734 - loss: 0.8137 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2923 - val_intensity_loss: 2.7811 - val_intensity_mae: 1.3561 - val_loss: 2.7497 - learning_rate: 1.0000e-06
# Epoch 150/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.8339 - emotional_state_loss: 0.4106 - intensity_loss: 0.7035 - intensity_mae: 0.6830 - loss: 0.8292 - val_emotional_state_accuracy: 0.5833 - val_emotional_state_loss: 1.2843 - val_intensity_loss: 2.7979 - val_intensity_mae: 1.3543 - val_loss: 2.7501 - learning_rate: 1.0000e-06
# Epoch 151/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - emotional_state_accuracy: 0.8367 - emotional_state_loss: 0.4115 - intensity_loss: 0.6998 - intensity_mae: 0.6866 - loss: 0.8283 - val_emotional_state_accuracy: 0.5875 - val_emotional_state_loss: 1.2865 - val_intensity_loss: 2.7949 - val_intensity_mae: 1.3593 - val_loss: 2.7507 - learning_rate: 1.0000e-06
# Epoch 152/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - emotional_state_accuracy: 0.8286 - emotional_state_loss: 0.4339 - intensity_loss: 0.7207 - intensity_mae: 0.7015 - loss: 0.8610 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2838 - val_intensity_loss: 2.8045 - val_intensity_mae: 1.3601 - val_loss: 2.7529 - learning_rate: 1.0000e-06
# Epoch 153/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.8404 - emotional_state_loss: 0.3977 - intensity_loss: 0.7057 - intensity_mae: 0.6852 - loss: 0.8174 - val_emotional_state_accuracy: 0.5792 - val_emotional_state_loss: 1.2862 - val_intensity_loss: 2.7907 - val_intensity_mae: 1.3528 - val_loss: 2.7485 - learning_rate: 1.0000e-06
# Epoch 154/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - emotional_state_accuracy: 0.8318 - emotional_state_loss: 0.4225 - intensity_loss: 0.7307 - intensity_mae: 0.6963 - loss: 0.8546 - val_emotional_state_accuracy: 0.5958 - val_emotional_state_loss: 1.2836 - val_intensity_loss: 2.7925 - val_intensity_mae: 1.3586 - val_loss: 2.7467 - learning_rate: 1.0000e-06
# Epoch 155/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - emotional_state_accuracy: 0.8305 - emotional_state_loss: 0.4349 - intensity_loss: 0.7089 - intensity_mae: 0.6940 - loss: 0.8562 - val_emotional_state_accuracy: 0.5792 - val_emotional_state_loss: 1.2939 - val_intensity_loss: 2.7869 - val_intensity_mae: 1.3560 - val_loss: 2.7542 - learning_rate: 1.0000e-06
# Epoch 156/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - emotional_state_accuracy: 0.8362 - emotional_state_loss: 0.4139 - intensity_loss: 0.7358 - intensity_mae: 0.7061 - loss: 0.8487 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2854 - val_intensity_loss: 2.7756 - val_intensity_mae: 1.3527 - val_loss: 2.7400 - learning_rate: 1.0000e-06
# Epoch 157/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - emotional_state_accuracy: 0.8286 - emotional_state_loss: 0.4268 - intensity_loss: 0.7207 - intensity_mae: 0.6999 - loss: 0.8539 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2756 - val_intensity_loss: 2.7784 - val_intensity_mae: 1.3510 - val_loss: 2.7317 - learning_rate: 1.0000e-06
# Epoch 158/300
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - emotional_state_accuracy: 0.8279 - emotional_state_loss: 0.4167 - intensity_loss: 0.7040 - intensity_mae: 0.6930 - loss: 0.8355 - val_emotional_state_accuracy: 0.5917 - val_emotional_state_loss: 1.2759 - val_intensity_loss: 2.7782 - val_intensity_mae: 1.3528 - val_loss: 2.7318 - learning_rate: 1.0000e-06
#
# [9] Validation results ...
#
#   ── Y1: Emotional State (acc=0.604) ──
#               precision    recall  f1-score   support
#
# calm_neutral       0.78      0.64      0.70        83
#      focused       0.49      0.49      0.49        39
#        mixed       0.55      0.58      0.56        38
#  overwhelmed       0.55      0.71      0.62        38
#     restless       0.55      0.57      0.56        42
#
#     accuracy                           0.60       240
#    macro avg       0.58      0.60      0.59       240
# weighted avg       0.62      0.60      0.61       240
#
#
#   ── Y2: Intensity Regression (MAE=1.355) ──
#   True   : [5, 1, 3, 5, 2, 3, 3, 2, 3, 4]
#   Pred   : [3, 3, 4, 3, 2, 3, 4, 4, 2, 1]
#
# [10] Saving plots ...
#   Plots saved.
#
# [11] Generating test predictions ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_325/606536674.py in <cell line: 0>()
#     631
#     632     records.append({
# --> 633         'id':                  test_raw.iloc[i]['id'],
#     634         'predicted_state':     state,
#     635         'predicted_intensity': intensity,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1235
#    1236         # Similar to Index.get_value, but we do not fall back to positional
# -> 1237         loc = self.index.get_loc(label)
#    1238
#    1239         if is_integer(loc):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'id'
